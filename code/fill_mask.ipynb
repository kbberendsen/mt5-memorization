# %%
#!pip install transformers
#!pip install Levenshtein

# %%
# Importing required packages
import pandas as pd
import numpy as np
import random
import math
import re
import torch
from tqdm import tqdm

from transformers import MT5Tokenizer, MT5ForConditionalGeneration, T5Tokenizer, T5ForConditionalGeneration
from Levenshtein import distance as levenshtein_distance

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
mask_per = 15
model_size = 'large'
tokenizer = MT5Tokenizer.from_pretrained(f"google/mt5-{model_size}")
model = MT5ForConditionalGeneration.from_pretrained(f"google/mt5-{model_size}")
# Out:
# c:\Users\PC\anaconda3\envs\env_thesis\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# model_size = '3b'
# tokenizer = T5Tokenizer.from_pretrained(f"google-t5/t5-{model_size}")
# model = T5ForConditionalGeneration.from_pretrained(f"google-t5/t5-{model_size}")

# model_size='xl'

# %%
TITLE = 'nrc'
TYPE = 'baseline' #'unique' #'duplicates'

MASKED_INPUT_PATH = f'..\\data\\{TYPE}\\masked_input\\masked_input_{mask_per}'

masked_data = pd.read_csv(f'{MASKED_INPUT_PATH}\\masked_sequences_{TITLE}.csv')

# %%
masked_data.head()
# Out:
#                        Input sequence (ground truth)  \
# 0  Met een spectaculaire reddingsoperatie wist he...
# 1  Met een spectaculaire reddingsoperatie wist he...
# 2  Op 1 juni begint de Nederlander Hermen Hulst a...
# 3  De liberaal-conservatieve Nieuw-Vlaamse Allian...
# 4  De elfde editie van de Willem IV Rally was een...
#
#                              Input sequence (masked)  \
# 0  Met een spectaculaire reddingsoperatie wist he...
# 1  <extra_id_0> reddingsoperatie wist het Isralis...
# 2  Op 1 juni begint de Nederlander Hermen Hulst a...
# 3  De liberaal-conservatieve <extra_id_0> blijft ...
# 4  De <extra_id_0> de Willem IV Rally was een gro...
#
#                                        Masked tokens  Number of masked tokens  \
# 0            ['actie voor de', '120 gijzelaars die']                        6
# 1  ['Met een spectaculaire', 'prijs aan Palestijn...                        6
# 2  ['van Sony Interactive', 'gamebedrijf door een...                        7
# 3  ['Nieuw-Vlaamse Alliantie (N-VA)', 'de regiona...                        6
# 4    ['elfde editie van', 'van de organisatie. Dit']                        7
#
#    Masking percentage  Duplicate count
# 0                15.0                1
# 1                15.0                1
# 2                15.0                1
# 3                15.0                1
# 4                15.0                1

# %%
# Handle multiple gpus if available
if torch.cuda.device_count() > 1:
    print(f"Using {torch.cuda.device_count()} GPUs")
    model = torch.nn.DataParallel(model)

model.to(device)
# Out:
# MT5ForConditionalGeneration(
#   (shared): Embedding(250112, 1024)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 1024)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 16)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-23): 23 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 1024)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 16)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-23): 23 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=1024, out_features=250112, bias=False)
# )

# %% [markdown]
# # Functions

# %%
# Combine tokens into final output sequence
def flatten(lst):
  flat_list = []
  for item in lst:
    if isinstance(item, list):
      flat_list.extend(flatten(item))
    else:
      flat_list.append(item)
  return flat_list

# %%
def similarity(masked_tokens, filled_tokens):

  distances = []
  # Iterate through each pair of tokens
  for masked_token, filled_token in zip(masked_tokens, filled_tokens):
    try:
      # Calculate Levenshtein Distance between the two tokens
      distance = levenshtein_distance(masked_token, filled_token)

      # Normalize distance by dividing by the length of the longer token
      max_length = max(len(masked_token), len(filled_token))
      normalized_distance = distance / max_length

      # Append the normalized distance to the list of distances
      distances.append(normalized_distance)
    except:
      distances.append(None)

  # Return the list of normalized distances
  return distances

# %%
def fill_mask(input_data, model_size=model_size, sequence_id=None, model=model, tokenizer=tokenizer, device=device):

  # Retrieve input sequence data
  input_sequence = input_data['Input sequence (ground truth)']
  input_sequence_masked = input_data['Input sequence (masked)']
  masked_tokens = [item.strip("'") for item in input_data['Masked tokens'].strip("[]").split(", ")]
  n_masks = input_data['Number of masked tokens']
  duplicate_count = input_data['Duplicate count']

  # Tokenize the input sequence
  input_ids = tokenizer(input_sequence_masked, return_tensors="pt").input_ids
  input_ids = input_ids.to(device)

  # Generate the output sequence
  #with torch.no_grad():
  #  sequence_ids = model.generate(input_ids, max_length=len(input_sequence_masked)+(len(masked_tokens))) # max_length = length masked input sequence + length masked input tokens

  # Generate the output sequence, handle multiple gpu's if available
  with torch.no_grad():
      if isinstance(model, torch.nn.DataParallel):
          sequence_ids = model.module.generate(input_ids, max_length=len(input_sequence_masked) + len(masked_tokens))
      else:
          sequence_ids = model.generate(input_ids, max_length=len(input_sequence_masked) + len(masked_tokens))

  sequence_ids = sequence_ids.cpu()

  # Decode the generated sequence
  generated_sequence = tokenizer.batch_decode(sequence_ids, skip_special_tokens=False)[0]

  # Combine the input sequence and generated sequence, replacing masked tokens with model output
  filled_tokens = []
  output_sequence = []
  input_tokens = input_sequence_masked.split()
  generated_tokens = generated_sequence.split()
  print(input_tokens)
  print(generated_tokens)

  try:
    input_token_index = 0
    mask_tag_id = 0
    for token in input_tokens:
      # If mask tag is found in input tokens, append every token between the mask tag and the next mask tag
      if "<extra_id_" in token:
        # If mask tag_id is higher than number of masked tokens, skip.
        if mask_tag_id > n_masks:
          continue
        else:
          # Define mask tags
          mask_tag = f"<extra_id_{mask_tag_id}>"
          mask_tag_next = f"<extra_id_{mask_tag_id+1}>"

          # Retrieve indices for tokens between mask tags
          start_index = [i for i, item in enumerate(generated_tokens) if mask_tag in item][0]

          # If next mask_id is not in the generated tokens, end_index is last generated token
          try:
            end_index = [i for i, item in enumerate(generated_tokens) if mask_tag_next in item][0]
          except:
            end_index = len(generated_tokens)

          # Append in between tokens
          tokens_to_append = generated_tokens[start_index+1:end_index]
          filled_tokens.append(tokens_to_append)
          output_sequence.append(tokens_to_append)

          # Update indices
          input_token_index +=1
          mask_tag_id = mask_tag_id+1

      # Append input sequence token
      else:
        output_sequence.append(input_tokens[input_token_index])
        input_token_index+=1

    # Flatten sequence
    output_sequence_flat = flatten(output_sequence)

    # Remove nested list
    filled_tokens = [' '.join(tokens) for tokens in filled_tokens]

    # Clean possible </s> tag form last token
    last_token = output_sequence_flat[-1]
    if last_token.endswith("</s>"):
      output_sequence_flat[-1] = last_token[:-4]
      filled_tokens[-1] = last_token[:-4]

    final_output_sequence = " ".join(output_sequence_flat)

    # Calculate similarity
    levenshtein_distances = similarity(masked_tokens, filled_tokens)
    try:
      levenshtein_avg = round((sum(levenshtein_distances))/(len(levenshtein_distances)), 2)
    except:
      levenshtein_avg = None

  # If error, e.g. if not all tags are in generated output, make output empty and therefore invalid
  except:
    filled_tokens = None
    final_output_sequence = None
    levenshtein_distances = None
    levenshtein_avg = None

  print(f"Sequence id:                      {sequence_id}")
  print(f"Input sequence (masked):          {input_sequence_masked}")
  print(f"Final model output sequence:      {final_output_sequence}")
  print(f"Input sequence (ground truth):    {input_sequence}")
  print(f"Masked tokens:                    {masked_tokens}")
  print(f"Filled tokens:                    {filled_tokens}")
  print(f"Levenshtein distance (avg):       {levenshtein_avg}")
  print("")

  results_df_temp = None
  # Check if the DataFrame exists
  if results_df_temp is None:
      results_df_temp = pd.DataFrame(columns=["Sequence id", "Model size",
                                              "Input sequence (ground truth)", "Input sequence (masked)",
                                              "Model output sequence", "Masked tokens", "Filled tokens",
                                              "Number of masked tokens", "Masking percentage", "Duplicate count",
                                              "Levenshtein distances", "Levenshtein distance (avg)"])

  new_data = {
        "Sequence id": [sequence_id],
        "Model size": [model_size],
        "Input sequence (ground truth)": [input_sequence],
        "Input sequence (masked)": [input_sequence_masked],
        "Model output sequence": [final_output_sequence],
        "Masked tokens": [masked_tokens],
        "Filled tokens": [filled_tokens],
        "Number of masked tokens": [n_masks],
        "Masking percentage": [mask_per],
        "Duplicate count": [duplicate_count],
        "Levenshtein distances": [levenshtein_distances],
        "Levenshtein distance (avg)": [levenshtein_avg]
  }

  results_df_temp = pd.DataFrame(new_data)


  return results_df_temp

# %% [markdown]
# # Generating

# %%
# Loop over sequences and fill_mask
results_df = None

for i in range(len(masked_data)):
  print(f"seq {i}")
  results_df_temp = fill_mask(masked_data.iloc[i], sequence_id=f"seq{i}-0") 
  # Add results to df
  results_df = pd.concat([results_df, results_df_temp], ignore_index=True)
# Out:
# seq 0
# ['Met', 'een', 'spectaculaire', 'reddingsoperatie', 'wist', 'het', 'Isralische', 'leger', 'zaterdag', 'vier', 'gijzelaars', 'te', 'bevrijden.', 'De', 'prijs', 'aan', 'Palestijnse', 'zijde', 'is', 'echter', 'ongekend', 'hoog.', 'Wat', 'betekent', 'deze', '<extra_id_0>', 'ongeveer', '<extra_id_1>', 'nog', 'vastzitten?', 'En', 'waarom', 'zwijgen', 'de', 'meeste', 'wereldleiders?', 'Vijf', 'vragen', 'beantwoord.']
# ['<pad>', '<extra_id_0>', 'prijs', 'voor', '<extra_id_1>', '200.000', 'Palestijnen', 'die', '<extra_id_2>', '200.000', 'mensen', 'die', 'er', '<extra_id_3>', 'prijs', 'voor', 'de', '200.000', 'mensen', 'die', 'er', 'nu', 'al', '<extra_id_15>', 'een', 'jaar', '<extra_id_2>', '200.000', 'mensen', 'die', 'er', '<extra_id_2>', '200.000', 'mensen', 'die', 'er', 'nu', '<extra_id_2>', '200.000', 'mensen', 'die', 'er', '<extra_id_16>', 'prijs', 'voor', 'de', '<extra_id_17>', 'prijs', 'voor', 'de', '<extra_id_18>', '200.000', 'mensen', 'die', 'er', '<extra_id_19>t', '<extra_id_20>', '200.000', 'mensen', 'die', 'er', 'nu', '<extra_id_2>', '200.000', 'mensen', 'die', 'er', 'nu', '<extra_id_2>', '200.000', 'mensen', 'die', 'er', 'nu', '<extra_id_2>', 'mensen', 'die', 'er', 'nu', '<extra_id_2>', 'mensen', 'die', 'er', 'nu', '<extra_id_2>', 'mensen', 'die', 'er', 'nu', '<extra_id_2>', 'mensen', 'die', 'er', 'nu', '<extra_id_27>', 'voor', 'de', 'mensen', 'die', '<extra_id_28>', '200.000', 'mensen', 'die', '<extra_id_29>', 'voor', 'de', 'mensen', 'die', 'er', '<extra_id_30>', 'nog', '<extra_id_31>', 'mensen', 'die', 'er', '<extra_id_32>', 'voor', 'de', '<extra_id_33>', 'mensen', 'die', 'er', 'nu', '<extra_id_22>', 'vastzitten?', 'Waarom', 'moeten', 'ze', 'hier', '<extra_id_9>', 'nog', '<extra_id_34>', '200.000', 'mensen', '<extra_id_35>t', '<extra_id_36>t?', '<extra_id_37>', 'voor', 'de', '<extra_id_38>t', '<extra_id_39>t', '<extra_id_40>', 'voor', 'de', '<extra_id_26>', '100.000', 'mensen', 'die', 'er', 'nu', '<extra_id_1>', '10.000', '<extra_id_2>t', '<extra_id_43>', 'voor', 'de', '<extra_id_1>', '200.000', 'mensen', 'die', 'er', '<extra_id_44>t', '<extra_id_45>t', 'die', 'er', 'nu', '<extra_id_50>t', '<extra_id_5>', 'prijs', 'voor', 'de', 'mensen', 'die', 'er', 'nu', '<extra_id_45>t', '<extra_id_5>', 'prijs', 'voor', 'de', 'mensen', 'die', 'er', '<extra_id_5>', 'prijs', '<extra_id_5>', 'prijs', '<extra_id_5>', 'prijs', '<extra_id_5>', 'prijs', '<extra_id_54>', 'prijs', '<extra_id_55>', 'voor', '<extra_id_56>', '200.000</s>']
# Sequence id:                      seq0-0
# Input sequence (masked):          Met een spectaculaire reddingsoperatie wist het Isralische leger zaterdag vier gijzelaars te bevrijden. De prijs aan Palestijnse zijde is echter ongekend hoog. Wat betekent deze <extra_id_0> ongeveer <extra_id_1> nog vastzitten? En waarom zwijgen de meeste wereldleiders? Vijf vragen beantwoord.
# Final model output sequence:      Met een spectaculaire reddingsoperatie wist het Isralische leger zaterdag vier gijzelaars te bevrijden. De prijs aan Palestijnse zijde is echter ongekend hoog. Wat betekent deze prijs voor ongeveer 200.000 Palestijnen die nog vastzitten? En waarom zwijgen de meeste wereldleiders? Vijf vragen beantwoord.
# Input sequence (ground truth):    Met een spectaculaire reddingsoperatie wist het Isralische leger zaterdag vier gijzelaars te bevrijden. De prijs aan Palestijnse zijde is echter ongekend hoog. Wat betekent deze actie voor de ongeveer 120 gijzelaars die nog vastzitten? En waarom zwijgen de meeste wereldleiders? Vijf vragen beantwoord.
# Masked tokens:                    ['actie voor de', '120 gijzelaars die']
# Filled tokens:                    ['prijs voor', '200.000 Palestijnen die']
# Levenshtein distance (avg):       0.66
#
# seq 1
# ['<extra_id_0>', 'reddingsoperatie', 'wist', 'het', 'Isralische', 'leger', 'zaterdag', 'vier', 'gijzelaars', 'te', 'bevrijden.', 'De', '<extra_id_1>', 'zijde', 'is', 'echter', 'ongekend', 'hoog.', 'Wat', 'betekent', 'deze', 'actie', 'voor', 'de', 'ongeveer', '120', 'gijzelaars', 'die', 'nog', 'vastzitten?', 'En', 'waarom', 'zwijgen', 'de', 'meeste', 'wereldleiders?', 'Vijf', 'vragen', 'beantwoord.']
# ['<pad>', '<extra_id_0>.', 'In', 'een', '<extra_id_1>', 'spanning', 'aan', 'Israëlische', '<extra_id_2>', 'de', '<extra_id_2>', 'de', '<extra_id_2>', 'aan', 'de', 'Israëlische', '<extra_id_3>', 'de', '<extra_id_4>', 'spanning', 'aan', 'Israëlische', '<extra_id_2>', 'de', 'Israëlische', '<extra_id_2>', 'de', 'Israëlische', '<extra_id_3>', 'de', 'Israëlische', '<extra_id_2>', 'de', 'Israëlische', '<extra_id_2>', 'de', 'Israëlische', '<extra_id_12>.', 'In', 'een', '<extra_id_1>', 'druk', 'vanuit', 'Israëlische', '<extra_id_1>', 'druk', 'van', 'Israëlische', '<extra_id_1>', 'druk', 'van', 'Israëlische', '<extra_id_1>', 'druk', 'van', 'Israëlische', '<extra_id_1>', 'druk', 'van', 'Israëlische', '<extra_id_1>', 'druk', 'van', 'Israëlische', '<extra_id_26>', 'druk', 'van', 'Israëlische', '<extra_id_27>', 'de', 'Israëlische', '<extra_id_28>', 'druk', 'van', 'Israëlische', '<extra_id_22>', 'de', '<extra_id_9>', 'aan', 'de', 'Israëlische', '<extra_id_23>', 'aan', 'de', 'Palestijnse', '<extra_id_5>lische', '<extra_id_15>', 'internationale', '<extra_id_2>', 'aan', 'Israëlische', '<extra_id_2>', 'aan', 'de', 'Israëlische', '<extra_id_2>', 'aan', 'de', 'Palestijnse', '<extra_id_2>', 'aan', 'de', '<extra_id_2>', 'Aan', 'de', 'andere', '<extra_id_2>', 'de', 'Israëlische', '<extra_id_2>', 'de', '<extra_id_8>', 'Israëlische', '<extra_id_2>', 'de', '<extra_id_2>', 'van', 'de', 'Palestijnse', '<extra_id_2>', 'aan', 'de', '<extra_id_2>', 'aan', '<extra_id_2>', 'aan', '<extra_id_2>', 'aan', '<extra_id_2>', 'aan', '<extra_id_2>', 'aan', '<extra_id_2>', 'aan', '<extra_id_2>', 'aan', '<extra_id_2>', 'aan', '<extra_id_2>', 'aan', '<extra_id_2>', 'aan', '<extra_id_2>', 'aan', '<extra_id_2>', 'aan', '<extra_id_55>', 'aan', 'de', 'Palestijnse', '<extra_id_2>', 'aan', 'Israëlische', 'en', 'Palestijnse', '<extra_id_15>', 'internationale', '<extra_id_55>', 'aan', '<extra_id_56>', 'internationale', '<extra_id_55>', 'in', '<extra_id_55>tijden', '<extra_id_26>', 'druk', '<extra_id_55>', '<extra_id_17>', 'in', '<extra_id_26>spanning', '<extra_id_26>spanning</s>']
# Sequence id:                      seq1-0
# Input sequence (masked):          <extra_id_0> reddingsoperatie wist het Isralische leger zaterdag vier gijzelaars te bevrijden. De <extra_id_1> zijde is echter ongekend hoog. Wat betekent deze actie voor de ongeveer 120 gijzelaars die nog vastzitten? En waarom zwijgen de meeste wereldleiders? Vijf vragen beantwoord.
# Final model output sequence:      In een reddingsoperatie wist het Isralische leger zaterdag vier gijzelaars te bevrijden. De spanning aan Israëlische zijde is echter ongekend hoog. Wat betekent deze actie voor de ongeveer 120 gijzelaars die nog vastzitten? En waarom zwijgen de meeste wereldleiders? Vijf vragen beantwoord.
# Input sequence (ground truth):    Met een spectaculaire reddingsoperatie wist het Isralische leger zaterdag vier gijzelaars te bevrijden. De prijs aan Palestijnse zijde is echter ongekend hoog. Wat betekent deze actie voor de ongeveer 120 gijzelaars die nog vastzitten? En waarom zwijgen de meeste wereldleiders? Vijf vragen beantwoord.
# Masked tokens:                    ['Met een spectaculaire', 'prijs aan Palestijnse']
# Filled tokens:                    ['In een', 'spanning aan Israëlische']
# Levenshtein distance (avg):       0.72
#
# seq 2
# ['Op', '1', 'juni', 'begint', 'de', 'Nederlander', 'Hermen', 'Hulst', 'als', 'ceo', '<extra_id_0>', 'Entertainment,', 'de', 'maker', 'van', 'PlayStation.', 'Voorheen', 'produceerde', 'Hulst', 'de', 'succesvolle', 'gameseries', 'Killzone', 'en', 'Horizon.', 'Hij', 'krijgt', 'de', 'taak', 'om', 's', 'werelds', 'grootste', '<extra_id_1>', 'tijd', 'in', 'de', 'game-industrie', 'te', 'leiden.']
# ['<pad>', '<extra_id_0>', 'van', 'Sony', 'Computer', '<extra_id_1>', 'speler', 'van', 'zijn', '<extra_id_2>', 'van', 'Sony', 'Computer', '<extra_id_3>', 'van', 'Sony', 'Computer', '<extra_id_4>', 'speler', 'van', 'zijn', '<extra_id_5>', 'van', 'Sony', 'Computer', '<extra_id_6>', 'van', 'Sony', 'Computer', '<extra_id_17>', 'van', 'Sony', 'Computer', '<extra_id_18>', 'van', 'Sony', 'Computer', '<extra_id_19>', 'van', 'zijn', '<extra_id_20>', 'speler', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_2>', 'van', 'zijn', '<extra_id_27>', 'van', 'zijn', '<extra_id_28>', 'speler', 'van', 'zijn', '<extra_id_22>', 'van', 'Sony', 'Computer', 'Entertainment', 'voor', 'de', 'eerste', '<extra_id_21>', 'speler', 'van', 'zijn', '<extra_id_22>', 'van', 'Sony', 'Computer', 'Entertainment', 'te', 'leiden.', 'Sony', 'Computer', '<extra_id_32>', 'van', 'Sony', 'Computer', '<extra_id_33>', 'van', 'zijn', '<extra_id_21>', 'speler', 'van', 'zijn', '<extra_id_22>', 'in', 'de', '<extra_id_21>', 'speler', 'van', 'zijn', '<extra_id_22>', 'in', 'de', 'laatste', '<extra_id_9>', 'van', 'zijn', '<extra_id_21>', 'speler', 'van', 'zijn', '<extra_id_22>', 'in', 'de', '<extra_id_9>', 'Sony.', 'Sony', '<extra_id_9>', 'Sony', 'de', '<extra_id_22>', 'Sony', 'de', '<extra_id_9>', 'Sony', 'de', '<extra_id_21>', 'speler', 'van', 'zijn', '<extra_id_22>', 'in', 'de', '<extra_id_9>', 'Sony', 'de', '<extra_id_22>', 'Sony', '<extra_id_9>', 'Sony', 'de', '<extra_id_22>', 'Sony', '<extra_id_9>', 'Sony', 'de', '<extra_id_22>', 'de', '<extra_id_49>', 'speler', 'van', 'zijn', '<extra_id_50>', 'van', 'zijn', '<extra_id_51>', 'in', 'de', '<extra_id_21>', 'speler', 'van', 'zijn', '<extra_id_5>', 'van', 'Sony', '<extra_id_54>', 'bedrijf', '<extra_id_55>', 'Sony', 'Computer', '<extra_id_26>', 'speler', '<extra_id_56>', '</s>']
# Sequence id:                      seq2-0
# Input sequence (masked):          Op 1 juni begint de Nederlander Hermen Hulst als ceo <extra_id_0> Entertainment, de maker van PlayStation. Voorheen produceerde Hulst de succesvolle gameseries Killzone en Horizon. Hij krijgt de taak om s werelds grootste <extra_id_1> tijd in de game-industrie te leiden.
# Final model output sequence:      Op 1 juni begint de Nederlander Hermen Hulst als ceo van Sony Computer Entertainment, de maker van PlayStation. Voorheen produceerde Hulst de succesvolle gameseries Killzone en Horizon. Hij krijgt de taak om s werelds grootste speler van zijn tijd in de game-industrie te leiden.
# Input sequence (ground truth):    Op 1 juni begint de Nederlander Hermen Hulst als ceo van Sony Interactive Entertainment, de maker van PlayStation. Voorheen produceerde Hulst de succesvolle gameseries Killzone en Horizon. Hij krijgt de taak om s werelds grootste gamebedrijf door een tumultueuze tijd in de game-industrie te leiden.
# Masked tokens:                    ['van Sony Interactive', 'gamebedrijf door een tumultueuze']
# Filled tokens:                    ['van Sony Computer', 'speler van zijn']
# Levenshtein distance (avg):       0.66
#
# seq 3
# ['De', 'liberaal-conservatieve', '<extra_id_0>', 'blijft', 'de', 'grootste', 'partij', 'in', 'het', 'Vlaams', 'Parlement', '(25,2', 'procent).', 'Dat', 'melden', 'Belgische', 'media', 'op', 'basis', 'van', 'de', 'helft', 'van', 'de', 'getelde', 'stemmen', 'van', '<extra_id_1>', 'die', 'vandaag', 'tegelijk', 'met', 'de', 'Europese', 'en', 'landelijke', 'verkiezingen', 'plaatsvonden.']
# ['<pad>', '<extra_id_0>', 'Partij', 'voor', 'de', 'Vrijheid', '<extra_id_1>', 'de', 'regionale', 'verkiezingen', '<extra_id_2>', 'Partij', 'voor', 'de', 'Vrijheid', '<extra_id_3>', 'Partij', 'voor', 'de', 'Vrijheid', '<extra_id_1>', 'de', 'regionale', 'verkiezingen', '<extra_id_2>', 'partij', 'Vrijheid', '<extra_id_3>', 'Partij', 'voor', 'de', 'Vrijheid', '<extra_id_14>', 'de', 'regionale', 'verkiezingen,', '<extra_id_15>', 'de', 'regionale', 'verkiezingen,', '<extra_id_2>', 'Partij', 'voor', 'de', 'Vrijheid,', '<extra_id_2>', 'Partij', 'voor', 'de', 'Vrijheid,', '<extra_id_2>', 'Partij', 'voor', 'de', 'Vrijheid,', '<extra_id_2>', 'Partij', '<extra_id_16>', 'Partij', 'voor', 'de', 'Vrijheid', '<extra_id_17>', 'Partij', '<extra_id_18>s', '<extra_id_19>,', '<extra_id_22>.', '<extra_id_23>.', '<extra_id_24>.', '<extra_id_55>', 'Parti</s>']
# Sequence id:                      seq3-0
# Input sequence (masked):          De liberaal-conservatieve <extra_id_0> blijft de grootste partij in het Vlaams Parlement (25,2 procent). Dat melden Belgische media op basis van de helft van de getelde stemmen van <extra_id_1> die vandaag tegelijk met de Europese en landelijke verkiezingen plaatsvonden.
# Final model output sequence:      De liberaal-conservatieve Partij voor de Vrijheid blijft de grootste partij in het Vlaams Parlement (25,2 procent). Dat melden Belgische media op basis van de helft van de getelde stemmen van de regionale verkiezingen die vandaag tegelijk met de Europese en landelijke verkiezingen plaatsvonden.
# Input sequence (ground truth):    De liberaal-conservatieve Nieuw-Vlaamse Alliantie (N-VA) blijft de grootste partij in het Vlaams Parlement (25,2 procent). Dat melden Belgische media op basis van de helft van de getelde stemmen van de regionale verkiezingen, die vandaag tegelijk met de Europese en landelijke verkiezingen plaatsvonden.
# Masked tokens:                    ['Nieuw-Vlaamse Alliantie (N-VA)', 'de regionale verkiezingen,']
# Filled tokens:                    ['Partij voor de Vrijheid', 'de regionale verkiezingen']
# Levenshtein distance (avg):       0.47
#
# seq 4
# ['De', '<extra_id_0>', 'de', 'Willem', 'IV', 'Rally', 'was', 'een', 'groot', 'succes.', 'Dat', 'meldt', 'Arne', 'Verwoert', '<extra_id_1>', 'jaar', 'is', 'er', 'ruim', '11.500', 'euro', 'opgehaald', 'voor', 'het', 'Ronald', 'McDonald', 'Huis', 'Sophia', 'Rotterdam.', ',,De', 'jongste', 'deelnemer', 'ooit,', 'van', 'dertien', 'jaar', 'oud,', 'is', 'samen', 'met', 'haar', 'vader', 'eerste', 'geworden.']
# ['<pad>', '<extra_id_0>', 'eerste', 'editie', 'van', '<extra_id_1>.', 'Dit', '<extra_id_2>', 'de', 'eerste', 'editie', 'van', '<extra_id_1>.', 'Dit', '<extra_id_2>.', 'De', 'eerste', 'editie', 'van', '<extra_id_3>', 'eerste', 'editie', 'van', '<extra_id_1>.', 'Dit', '<extra_id_2>.', 'Met', '<extra_id_3>', 'eerste', 'editie', 'van', '<extra_id_14>.', 'Ook', '<extra_id_1>.', 'Dit', '<extra_id_2>.', 'Ook', '<extra_id_1>.', 'Dit', '<extra_id_2>.', 'Ook', '<extra_id_1>.', 'Dit', '<extra_id_2>.', 'Met', 'dit', '<extra_id_16>', 'eerste', 'editie', 'van', '<extra_id_17>', 'eerste', 'editie', 'van', '<extra_id_18>', 'van', '<extra_id_13>', 'eerste', 'editie', 'van', '<extra_id_17>', 'eerste', 'editie', 'van', '<extra_id_18>', 'van', '<extra_id_19>.', 'Dit', '<extra_id_21>.', 'Dit', '<extra_id_22>.’’', '<extra_id_23>', 'van', '<extra_id_24>.', '<extra_id_25>', 'eerste', 'editie', 'van', '<extra_id_26>.', 'Dit', '<extra_id_27>.', 'Dit', '<extra_id_28>.', 'Dit', '<extra_id_29>', 'van', '<extra_id_30>.', 'Dit', '<extra_id_31>.', 'Ook', '<extra_id_32>', 'editie', 'van', '<extra_id_33>.', 'Dit', '<extra_id_22>.', 'Dit', '<extra_id_9>', 'is', 'een', 'groot', 'succes.’’', 'Dit', '<extra_id_21>.', 'Dit', '<extra_id_22>', 'is', 'een', 'groot', 'succes.’’', '<extra_id_9>', 'van', 'de', 'eerste', 'editie', 'van', 'het', '<extra_id_9>', 'rally', '<extra_id_34>.', 'Dit', '<extra_id_2>', 'dit', '<extra_id_2>.', 'Dit', '<extra_id_2>.', 'Dit', '<extra_id_2>', 'is', 'dit', '<extra_id_2>.', 'Dit', '<extra_id_2>', 'is', 'dit', '<extra_id_2>', 'is', 'dit', '<extra_id_2>', 'is', 'dit', '<extra_id_2>', 'is', 'dit', '<extra_id_50>', 'dit', '<extra_id_22>.', '<extra_id_52>.’’', '<extra_id_39>', 'van', '<extra_id_54>.', 'Dit', '<extra_id_55>.,,De', 'eerste', 'editie', 'van', '<extra_id_17>', 'eerste', 'dag', 'van', '<extra_id_13>', 'editie', '<extra_id_56></s>']
# Sequence id:                      seq4-0
# Input sequence (masked):          De <extra_id_0> de Willem IV Rally was een groot succes. Dat meldt Arne Verwoert <extra_id_1> jaar is er ruim 11.500 euro opgehaald voor het Ronald McDonald Huis Sophia Rotterdam. ,,De jongste deelnemer ooit, van dertien jaar oud, is samen met haar vader eerste geworden.
# Final model output sequence:      De eerste editie van de Willem IV Rally was een groot succes. Dat meldt Arne Verwoert Dit jaar is er ruim 11.500 euro opgehaald voor het Ronald McDonald Huis Sophia Rotterdam. ,,De jongste deelnemer ooit, van dertien jaar oud, is samen met haar vader eerste geworden.
# Input sequence (ground truth):    De elfde editie van de Willem IV Rally was een groot succes. Dat meldt Arne Verwoert van de organisatie. Dit jaar is er ruim 11.500 euro opgehaald voor het Ronald McDonald Huis Sophia Rotterdam. ,,De jongste deelnemer ooit, van dertien jaar oud, is samen met haar vader eerste geworden.
# Masked tokens:                    ['elfde editie van', 'van de organisatie. Dit']
# Filled tokens:                    ['eerste editie van', 'Dit']
# Levenshtein distance (avg):       0.55
#
# seq 5
# ['Lieke', '<extra_id_0>', 'overwinning', 'afscheid', 'van', 'het', 'thuispubliek.', 'Maar', 'ze', 'laat', 'een', 'kwetsbaar', 'team', 'achter,', 'waarvan', 'niemand', 'vooralsnog', 'kan', 'inschatten', 'waartoe', 'het', 'in', 'staat', 'is.']
# ['<pad>', '<extra_id_0>', 'de', 'Jong', 'nam', 'met', 'een', '<extra_id_1>', 'de', 'Jong', 'nam', 'met', 'een', 'ruime', '<extra_id_15>.', 'Met', 'de', 'eerste', 'echte', '<extra_id_16>', 'de', 'Jong', 'nam', 'met', 'een', 'ruime', '<extra_id_17>', 'de', 'Jong', 'nam', 'met', 'een', 'ruime', '<extra_id_1>', 'de', 'Jong', 'met', 'een', 'ruime', '<extra_id_18>.', '<extra_id_19>.', '<extra_id_20>', 'nam', 'met', 'een', '<extra_id_21>.', '<extra_id_22>.', '<extra_id_23>', 'de', '<extra_id_24>', 'met', 'een', '<extra_id_25>', 'de', 'Jong', 'nam', 'met', 'een', '<extra_id_26>', 'met', 'een', '<extra_id_15>', 'met', 'een', '<extra_id_15>.', 'Met', 'de', '<extra_id_15>', 'nam', 'de', '<extra_id_16>', 'de', 'Jong', 'met', 'een', '<extra_id_17>', 'de', 'Jong', 'nam', 'met', 'een', 'ruime', '<extra_id_26>', 'nam', 'met', 'een', 'ruime', '<extra_id_27>', 'met', 'een', 'ruime', '<extra_id_26>', 'nam', 'met', 'een', '<extra_id_27>', 'met', 'een', 'ruime', '<extra_id_28>.', 'Met', 'de', '<extra_id_29>', 'nam', 'het', 'Ajax', 'met', 'een', 'ruime</s>']
# Sequence id:                      seq5-0
# Input sequence (masked):          Lieke <extra_id_0> overwinning afscheid van het thuispubliek. Maar ze laat een kwetsbaar team achter, waarvan niemand vooralsnog kan inschatten waartoe het in staat is.
# Final model output sequence:      Lieke de Jong nam met een overwinning afscheid van het thuispubliek. Maar ze laat een kwetsbaar team achter, waarvan niemand vooralsnog kan inschatten waartoe het in staat is.
# Input sequence (ground truth):    Lieke Martens kon met een overwinning afscheid van het thuispubliek. Maar ze laat een kwetsbaar team achter, waarvan niemand vooralsnog kan inschatten waartoe het in staat is.
# Masked tokens:                    ['Martens kon met een']
# Filled tokens:                    ['de Jong nam met een']
# Levenshtein distance (avg):       0.47
#
# seq 6
# ['NRC', 'bespreekt', 'deze', 'weken', 'de', 'eindexamens', 'na', 'met', 'deskundigen.', 'Internist', 'Jos', 'Kooter', '<extra_id_0>', 'gl-', 'en', 'tl-examen', 'natuur-', 'en', 'scheikunde.']
# ['<pad><extra_id_0>', 'over', 'het', '<extra_id_1>', 'over', 'het', '<extra_id_1>-,', '<extra_id_2>-,', '<extra_id_3>', 'over', 'het', '<extra_id_1>-,', '<extra_id_2>-,', '<extra_id_17>', 'over', 'het', '<extra_id_1>', 'over', 'het', '<extra_id_15>-,', '<extra_id_16>', 'over', 'het', '<extra_id_17>', 'over', 'het', '<extra_id_1>', 'over', 'het', '<extra_id_1>', 'over', 'het', '<extra_id_15>-,', '<extra_id_16>', 'over', 'het', '<extra_id_17>', 'over', 'het', '<extra_id_18>-,', '<extra_id_19>-,', '<extra_id_20>', 'over', 'het', 'l-,', '<extra_id_21>-,', '<extra_id_22>-', 'en', 'eindexamens', 'biologie', 'en', 'chemie.', 'Externe', 'deskundigen', 'over', 'het', '<extra_id_23>-,', '<extra_id_18>-,', '<extra_id_19>-,', '<extra_id_20>-,', '<extra_id_21>-,', '<extra_id_22>-,', '<extra_id_23>-,', '<extra_id_24>-,', '<extra_id_26>-,', '<extra_id_27>-,', '<extra_id_28>-,', '<extra_id_29>-,', '<extra_id_30>-,', '<extra_id_31>-', 'en', '<extra_id_32>', 'over', 'het', '<extra_id_33>']
# Sequence id:                      seq6-0
# Input sequence (masked):          NRC bespreekt deze weken de eindexamens na met deskundigen. Internist Jos Kooter <extra_id_0> gl- en tl-examen natuur- en scheikunde.
# Final model output sequence:      NRC bespreekt deze weken de eindexamens na met deskundigen. Internist Jos Kooter over het gl- en tl-examen natuur- en scheikunde.
# Input sequence (ground truth):    NRC bespreekt deze weken de eindexamens na met deskundigen. Internist Jos Kooter over het vmbo gl- en tl-examen natuur- en scheikunde.
# Masked tokens:                    ['over het vmbo']
# Filled tokens:                    ['over het']
# Levenshtein distance (avg):       0.38
#
# seq 7
# ['De', 'Conservatieve', 'Britse', 'premier', 'Sunak', 'schreef', 'twee', 'weken', 'geleden', 'onverwachts', 'verkiezingen', '<extra_id_0>', 'met', '<extra_id_1>', 'meteen', 'volop', 'van', 'start.', 'Maandag', 'kwam', 'Nigel', 'Farage', 'met', 'een', 'verrassing:', 'hij', 'doet', 'alsnog', 'mee.']
# ['<pad><extra_id_0>', 'uit,', '<extra_id_1>', 'de', 'campagne', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_3>', 'uit', 'en', 'ging', '<extra_id_1>', 'de', 'campagne', '<extra_id_2>', 'de', 'verkiezingen.', 'De', 'campagne', 'ging', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_3>', 'uit', 'en', 'ging', 'daarna', '<extra_id_4>', 'de', 'campagne', '<extra_id_5>', 'uit', 'en', 'ging', '<extra_id_1>', 'de', 'campagne', '<extra_id_2>', 'de', 'Conservatieve', 'partij.', 'De', 'campagne', 'ging', '<extra_id_15>', 'de', 'campagne', '<extra_id_16>', 'uit', 'en', 'ging', '<extra_id_17>', 'uit', 'en', 'ging', '<extra_id_18>.', '<extra_id_19>.', '<extra_id_20>', 'de', 'campagne', 'ging', 'al', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_21>', 'de', 'campagne', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Conservatieve', 'partij', '<extra_id_2>', 'de', 'Brexit', '<extra_id_2>', 'de', 'Brexit', 'partij', '<extra_id_2>', 'de', 'Brexit', 'partij', '<extra_id_2>', 'de', 'Brexit', 'partij', '<extra_id_2>', 'de', 'Brexit', 'partij', '<extra_id_2>', 'de', 'Brexit', 'partij', '<extra_id_2>', 'de', 'Brexit', 'partij', '<extra_id_2>', 'de', 'Brexit', 'partij', '<extra_id_2>', 'de', 'Brexit', 'partij', '<extra_id_2>', 'de', 'Brexit', 'partij', '<extra_id_2>', 'de', 'Brexit', 'partij', '<extra_id_2>', 'de', '<extra_id_2>', 'de', '<extra_id_2>', 'de', '<extra_id_2>', 'de', '<extra_id_2>']
# Sequence id:                      seq7-0
# Input sequence (masked):          De Conservatieve Britse premier Sunak schreef twee weken geleden onverwachts verkiezingen <extra_id_0> met <extra_id_1> meteen volop van start. Maandag kwam Nigel Farage met een verrassing: hij doet alsnog mee.
# Final model output sequence:      De Conservatieve Britse premier Sunak schreef twee weken geleden onverwachts verkiezingen uit, met de campagne meteen volop van start. Maandag kwam Nigel Farage met een verrassing: hij doet alsnog mee.
# Input sequence (ground truth):    De Conservatieve Britse premier Sunak schreef twee weken geleden onverwachts verkiezingen uit. De campagnestrijd met Labour ging meteen volop van start. Maandag kwam Nigel Farage met een verrassing: hij doet alsnog mee.
# Masked tokens:                    ['uit. De campagnestrijd', 'Labour ging']
# Filled tokens:                    ['uit,', 'de campagne']
# Levenshtein distance (avg):       0.89
#
# seq 8
# ['Wie', 'noodgedwongen', 'zzper', 'wordt,', 'heeft', 'het', 'minder', 'goed', 'dan', 'zelfstandigen', 'die', 'daar', '<extra_id_0>', 'blijkt', 'uit', 'onderzoek', 'van', 'Rabobank.']
# ['<pad><extra_id_0>', 'niet', 'instappen,', '<extra_id_1>,', 'zo', '<extra_id_15>.', 'Dat', '<extra_id_16>', 'niet', 'instappen,', '<extra_id_1>,', 'zo', '<extra_id_1>,', '<extra_id_15>.', 'Dat', '<extra_id_16>', 'niet', 'instappen,', '<extra_id_17>', 'niet', 'instappen,', 'zo', '<extra_id_18>.', 'Dat', '<extra_id_19>', 'toch', 'instappen,', 'gaat', 'het', 'minder', 'goed.', 'Dat', '<extra_id_20>,', '<extra_id_21>,', '<extra_id_22>,', '<extra_id_7>.', 'Dat', '<extra_id_7>,', '<extra_id_17>', 'niet', 'instappen,', '<extra_id_18>,', '<extra_id_19>,', 'gaat', 'het', 'minder', 'goed.', 'Dat', '<extra_id_20>,', '<extra_id_21>,', 'gaat', 'het', 'minder', 'goed.', 'Dat', '<extra_id_22>,', 'gaat', 'het', 'minder', 'goed,', '<extra_id_23>,', '<extra_id_18>,', 'gaat', 'het', 'minder', 'goed.', 'Dat', '<extra_id_24>,', 'gaat', 'het', 'minder', 'goed,', 'zo', '<extra_id_25>', 'niet', 'instappen,', '<extra_id_26>,', 'zo', '<extra_id_27>,']
# Sequence id:                      seq8-0
# Input sequence (masked):          Wie noodgedwongen zzper wordt, heeft het minder goed dan zelfstandigen die daar <extra_id_0> blijkt uit onderzoek van Rabobank.
# Final model output sequence:      Wie noodgedwongen zzper wordt, heeft het minder goed dan zelfstandigen die daar niet instappen, blijkt uit onderzoek van Rabobank.
# Input sequence (ground truth):    Wie noodgedwongen zzper wordt, heeft het minder goed dan zelfstandigen die daar bewust voor kiezen, blijkt uit onderzoek van Rabobank.
# Masked tokens:                    ['bewust voor kiezen,']
# Filled tokens:                    ['niet instappen,']
# Levenshtein distance (avg):       0.74
#
# seq 9
# ['Amsterdammers', 'mogen', 'donderdag', 'behalve', 'voor', '<extra_id_0>', 'Parlement', 'ook', 'stemmen', 'over', 'groen', 'in', 'hun', 'stad.']
# ['<pad><extra_id_0>', 'Westminster', '<extra_id_1>', 'Westminster', '<extra_id_2>', 'groen', 'in', 'hun', 'stad', 'in', 'het', 'Parlement.', 'In', 'het', 'Parlement', 'moeten', 'Amsterdammers', 'donderdag', 'stemmen', 'over', 'groen', 'in', 'het', '<extra_id_17>', 'groen', 'in', 'het', '<extra_id_18>', 'groen', 'in', 'het', '<extra_id_19>.', 'In', 'het', 'Parlement', '<extra_id_20>', 'groen', 'in', 'het', '<extra_id_21>.', '<extra_id_22>.', '<extra_id_23>', 'groen', 'in', 'het', '<extra_id_24>.', 'In', 'het', '<extra_id_25>', 'groen', 'in', 'het', '<extra_id_26>', 'groen', 'in', 'het', '<extra_id_27>', 'groen', 'in', 'het', '<extra_id_28>', 'in', '<extra_id_29>', 'in', 'het', '<extra_id_26>', 'groen', 'in', 'het', '<extra_id_15>', 'groen', 'in', 'het', 'Parlement.', 'In', 'het', 'Parlement', '<extra_id_30>', 'groen', 'in', 'het', 'Parlement', '<extra_id_31>']
# Sequence id:                      seq9-0
# Input sequence (masked):          Amsterdammers mogen donderdag behalve voor <extra_id_0> Parlement ook stemmen over groen in hun stad.
# Final model output sequence:      Amsterdammers mogen donderdag behalve voor Westminster Parlement ook stemmen over groen in hun stad.
# Input sequence (ground truth):    Amsterdammers mogen donderdag behalve voor het Europees Parlement ook stemmen over groen in hun stad.
# Masked tokens:                    ['het Europees']
# Filled tokens:                    ['Westminster']
# Levenshtein distance (avg):       0.83
#
# seq 10
# ['Drie', 'docenten', 'van', 'de', 'zeevaartschool', 'op', 'Terschelling', 'verloren', 'hun', 'baan', 'na', 'onderzoek', 'over', 'grensoverschrijdend', 'gedrag.', 'Dat', 'onderzoek', 'bleek', 'niet', 'te', 'deugen', 'maar', 'de', 'sociale', 'verhoudingen', 'op', '<extra_id_0>', 'staan', 'nu', '<extra_id_1>']
# ['<pad>', '<extra_id_0>', 'de', 'school', '<extra_id_1>', 'sterk', 'onder', 'druk.</s>']
# Sequence id:                      seq10-0
# Input sequence (masked):          Drie docenten van de zeevaartschool op Terschelling verloren hun baan na onderzoek over grensoverschrijdend gedrag. Dat onderzoek bleek niet te deugen maar de sociale verhoudingen op <extra_id_0> staan nu <extra_id_1>
# Final model output sequence:      Drie docenten van de zeevaartschool op Terschelling verloren hun baan na onderzoek over grensoverschrijdend gedrag. Dat onderzoek bleek niet te deugen maar de sociale verhoudingen op de school staan nu sterk onder druk.
# Input sequence (ground truth):    Drie docenten van de zeevaartschool op Terschelling verloren hun baan na onderzoek over grensoverschrijdend gedrag. Dat onderzoek bleek niet te deugen  maar de sociale verhoudingen op het eiland staan nu wel op scherp.
# Masked tokens:                    ['het eiland', 'wel op scherp.']
# Filled tokens:                    ['de school', 'druk.']
# Levenshtein distance (avg):       0.86
#
# seq 11
# ['Netbeheerder', 'Tennet', 'heeft', '<extra_id_0>', 'van', 'een', 'stroomkabel', '<extra_id_1>', 'schade', 'aangebracht', 'aan', 'kwetsbare', 'natuur', 'op', 'landgoed', 'Twickel,', 'concludeerde', 'de', 'provincie', 'Overijssel', 'donderdag.', 'In', 'Twente', 'is', 'te', 'zien', 'hoe', 'klimaatdoelen', 'botsen', 'met', 'de', 'natuuropgave.']
# ['<pad>', '<extra_id_0>', 'door', 'het', 'leggen', '<extra_id_1>', 'in', 'de', 'noordwestelijke', 'richting', '<extra_id_2>', 'in', 'de', 'lengte', '<extra_id_3>', 'door', 'het', 'leggen', '<extra_id_4>', 'in', 'de', 'noordwestelijke', 'richting', '<extra_id_2>', 'te', 'veel', '<extra_id_3>', 'door', 'het', 'leggen', '<extra_id_4>', 'te', 'veel', '<extra_id_2>', 'te', 'veel', '<extra_id_2>', 'in', 'de', 'lengte', '<extra_id_3>', 'door', 'het', 'leggen', '<extra_id_4>', 'te', 'veel', '<extra_id_2>', 'te', 'veel', '<extra_id_2>', 'in', 'de', 'lengte', '<extra_id_16>', 'door', 'het', 'leggen', '<extra_id_17>', 'door', 'het', 'leggen', '<extra_id_18>', 'in', 'de', 'lengte', '<extra_id_19>', 'te', 'veel', '<extra_id_21>', 'te', 'veel', '<extra_id_22>.</s>']
# Sequence id:                      seq11-0
# Input sequence (masked):          Netbeheerder Tennet heeft <extra_id_0> van een stroomkabel <extra_id_1> schade aangebracht aan kwetsbare natuur op landgoed Twickel, concludeerde de provincie Overijssel donderdag. In Twente is te zien hoe klimaatdoelen botsen met de natuuropgave.
# Final model output sequence:      Netbeheerder Tennet heeft door het leggen van een stroomkabel in de noordwestelijke richting schade aangebracht aan kwetsbare natuur op landgoed Twickel, concludeerde de provincie Overijssel donderdag. In Twente is te zien hoe klimaatdoelen botsen met de natuuropgave.
# Input sequence (ground truth):    Netbeheerder Tennet heeft met de aanleg van een stroomkabel mogelijk onomkeerbare schade aangebracht aan kwetsbare natuur op landgoed Twickel, concludeerde de provincie Overijssel donderdag. In Twente is te zien hoe klimaatdoelen botsen met de natuuropgave.
# Masked tokens:                    ['met de aanleg', 'mogelijk onomkeerbare']
# Filled tokens:                    ['door het leggen', 'in de noordwestelijke richting']
# Levenshtein distance (avg):       0.8
#
# seq 12
# ['<extra_id_0>', 'met', 'elkaar', 'hoeven', 'concurreren', 'om', 'spaarders,', 'ontvangen', 'klanten', 'te', 'lage', 'rentes,', 'concludeert', 'ACM.', 'De', 'toezichthouder', 'stelt', 'onder', 'meer', 'het', 'opzetten', 'van', 'een', 'onafhankelijke', 'vergelijkingssite', 'voor.']
# ['<pad>', '<extra_id_0>', 'niet', '<extra_id_1>banken', 'die', 'niet', '<extra_id_2>en', '<extra_id_3>en', 'die', 'niet', '<extra_id_4>en', '<extra_id_5>en.', 'Banken', 'die', 'niet', '<extra_id_1>en', '<extra_id_2>en', '<extra_id_3>en', 'die', 'niet', '<extra_id_4>en', '<extra_id_5>en', 'die', 'niet', '<extra_id_1>en', 'die', 'niet', '<extra_id_2>en.', 'Banken', 'die', 'niet', '<extra_id_6>en', '<extra_id_7>en</s>']
# Sequence id:                      seq12-0
# Input sequence (masked):          <extra_id_0> met elkaar hoeven concurreren om spaarders, ontvangen klanten te lage rentes, concludeert ACM. De toezichthouder stelt onder meer het opzetten van een onafhankelijke vergelijkingssite voor.
# Final model output sequence:      niet met elkaar hoeven concurreren om spaarders, ontvangen klanten te lage rentes, concludeert ACM. De toezichthouder stelt onder meer het opzetten van een onafhankelijke vergelijkingssite voor.
# Input sequence (ground truth):    Omdat grote banken nauwelijks met elkaar hoeven concurreren om spaarders, ontvangen klanten te lage rentes, concludeert ACM. De toezichthouder stelt onder meer het opzetten van een onafhankelijke vergelijkingssite voor.
# Masked tokens:                    ['Omdat grote banken nauwelijks']
# Filled tokens:                    ['niet']
# Levenshtein distance (avg):       0.93
#
# seq 13
# ['Een', 'kaalslag', 'dreigt', 'onder', 'installateurs', 'van', 'zonnepanelen', 'in', 'Nederland.', 'Niet', 'alleen', 'zijn', 'de', 'energieprijzen', 'gezakt,', '<extra_id_0>', 'heeft', 'haar', 'langste', 'tijd', 'gehad.']
# ['<pad>', '<extra_id_0>', 'ook', 'de', 'vraag', 'naar', 'zonnepanelen', '<extra_id_1>', 'de', 'zon', '<extra_id_15>', 'het', 'verbruik.', 'Zonnepanelen', 'in', 'Nederland', '<extra_id_16>', 'ook', 'de', 'zon', '<extra_id_17>', 'ook', 'de', 'zon', '<extra_id_18>', 'de', 'zon.', 'Zonnepanelen', '<extra_id_19>den', '<extra_id_20>', 'de', 'zon', '<extra_id_21>.', '<extra_id_22>de', '<extra_id_7>de', '<extra_id_7>de', '<extra_id_7>de', '<extra_id_7>de.', 'Zonnepanelen', '<extra_id_23>den', 'De', 'zon', '<extra_id_18>de', '<extra_id_26>de.', 'De', 'zon', '<extra_id_27>de.', 'De', 'zon', '<extra_id_28>de.', 'Zonnepanelen', '<extra_id_29>den', 'De', 'zon', '<extra_id_33>de.', 'De', 'zon', 'heeft', 'haar', 'langste', 'tijd', 'gehad', 'De', 'zon', 'heeft</s>']
# Sequence id:                      seq13-0
# Input sequence (masked):          Een kaalslag dreigt onder installateurs van zonnepanelen in Nederland. Niet alleen zijn de energieprijzen gezakt, <extra_id_0> heeft haar langste tijd gehad.
# Final model output sequence:      Een kaalslag dreigt onder installateurs van zonnepanelen in Nederland. Niet alleen zijn de energieprijzen gezakt, ook de vraag naar zonnepanelen heeft haar langste tijd gehad.
# Input sequence (ground truth):    Een kaalslag dreigt onder installateurs van zonnepanelen in Nederland. Niet alleen zijn de energieprijzen gezakt, ook de lucratieve salderingsregeling heeft haar langste tijd gehad.
# Masked tokens:                    ['ook de lucratieve salderingsregeling']
# Filled tokens:                    ['ook de vraag naar zonnepanelen']
# Levenshtein distance (avg):       0.58
#
# seq 14
# ['In', 'Wenen', 'is', 'een', '<extra_id_0>', 'dat', 'gewijd', 'is', 'aan', 'het', 'Wiener', 'Aktionismus,', 'dat', 'in', 'de', 'jaren', 'zestig', 'Oostenrijk', 'opschudde', 'met', 'voorstellingen', 'vol', 'bloed', 'en', 'uitwerpselen.', 'Had', 'het', 'beter', '<extra_id_1>', 'worden?']
# ['<pad>', '<extra_id_0>', 'museum', '<extra_id_1>', 'kunnen', '<extra_id_2>', 'museum', 'kunnen', '<extra_id_3>', 'museum', 'geopend,', '<extra_id_1>', 'kunnen', '<extra_id_2>', 'moeten', '<extra_id_3>', 'museum', 'geopend,', '<extra_id_1>', 'kunnen', '<extra_id_2>', 'kunnen', '<extra_id_16>', 'museum', 'geopend,', '<extra_id_17>', 'museum', 'geopend,', '<extra_id_1>', 'kunnen', '<extra_id_2>', 'museum', 'geopend,', '<extra_id_1>', 'kunnen', '<extra_id_2>', 'museum', 'kunnen', 'worden,', '<extra_id_1>', 'kunnen', '<extra_id_2>', 'museum', 'kunnen', 'worden,', '<extra_id_1>', 'kunnen', '<extra_id_2>', 'museum', 'kunnen', 'worden,', '<extra_id_1>', 'kunnen', '<extra_id_2>', 'museum', 'kunnen', 'worden,', '<extra_id_1>', 'kunnen', '<extra_id_2>', 'museum', 'kunnen', 'worden,', '<extra_id_17>', 'museum', '<extra_id_18>', 'geopend', '<extra_id_19>', 'kunnen', '<extra_id_22>', 'geopend', '<extra_id_23>', 'geopend', 'moeten', '<extra_id_24>', 'geopend', '<extra_id_55>', 'museum,', '<extra_id_26>', 'kunn</s>']
# Sequence id:                      seq14-0
# Input sequence (masked):          In Wenen is een <extra_id_0> dat gewijd is aan het Wiener Aktionismus, dat in de jaren zestig Oostenrijk opschudde met voorstellingen vol bloed en uitwerpselen. Had het beter <extra_id_1> worden?
# Final model output sequence:      In Wenen is een museum dat gewijd is aan het Wiener Aktionismus, dat in de jaren zestig Oostenrijk opschudde met voorstellingen vol bloed en uitwerpselen. Had het beter kunnen worden?
# Input sequence (ground truth):    In Wenen is een nieuw museum geopend dat gewijd is aan het Wiener Aktionismus, dat in de jaren zestig Oostenrijk opschudde met voorstellingen vol bloed en uitwerpselen. Had het beter vergeten kunnen worden?
# Masked tokens:                    ['nieuw museum geopend', 'vergeten kunnen']
# Filled tokens:                    ['museum', 'kunnen']
# Levenshtein distance (avg):       0.65
#
# seq 15
# ['Is', 'dit', 'fascisme?', 'Het', 'is', 'de', 'vraag', 'die', 'telkens', 'terugkomt.', 'Baudets', 'opmerking', 'over', 'homeopathische', 'verdunning:', 'is', 'dit', 'fascisme?', 'De', 'bestorming', 'van', 'het', 'Capitool:', 'is', 'dit', 'fascisme?', '<extra_id_0>', '-lhbti-activisten:', '<extra_id_1>', 'fascisme?']
# ['<pad>', '<extra_id_0>', 'De', 'acties', 'van', 'anti', '<extra_id_1>', 'is', 'dit', '<extra_id_2>?', 'De', 'acties', 'van', 'anti', '<extra_id_3>?', 'De', 'acties', 'van', 'anti', '<extra_id_4>', 'is', 'dit', '<extra_id_2>?', 'De', 'acties', 'van', 'anti-gay-', 'en', 'anti', '<extra_id_5>', 'De', 'acties', 'van', 'anti', '<extra_id_6>?', 'De', 'acties', 'van', 'anti', '<extra_id_7>-', 'en', 'anti-gay', '<extra_id_8>', 'is', 'dit', '<extra_id_2>?', 'Is', 'dit', '<extra_id_2>?', 'Is', 'dit', '<extra_id_2>?', 'Anti-gay-', 'en', 'anti-lhbti-activisten:', 'is', 'dit', '<extra_id_2>?', 'Anti-gay-', 'en', 'anti-lhbti-', '<extra_id_2>', 'tegen', 'het', '<extra_id_16>', 'Anti', '<extra_id_26>', 'is', 'dit', '<extra_id_27>?', 'Anti', '<extra_id_28>', 'is', 'dit', '<extra_id_29>isme?', 'Anti', '<extra_id_30>-anti-', '<extra_id_31>?', 'Anti', '<extra_id_32>?', 'Anti', '<extra_id_33>:', 'is', 'dit', '<extra_id_22>isme?', 'Anti-gay-', 'en', 'anti-lhbti-activisten:', 'is', 'dit', '<extra_id_2>?', 'Is', 'dit', '<extra_id_22>isme?', 'Anti', '<extra_id_52>', 'tegen', '<extra_id_53>?', 'Anti', '<extra_id_26>', 'is', 'dit', 'fascisme?', 'Anti', '<extra_id_54>', 'is', 'dit', '<extra_id_55>?', 'Anti-gay-', 'en', 'anti', '<extra_id_1>', 'is', 'dit', 'fascisme?', 'Anti-gay-', 'en', 'anti', '<extra_id_1>', 'is', 'dit', 'fascisme?', 'Anti-gay', '<extra_id_17>', 'Anti', '<extra_id_15>', 'is', 'dit', 'fascisme?', 'Anti', '<extra_id_17>', 'Anti', '<extra_id_56>:', 'is</s>']
# Sequence id:                      seq15-0
# Input sequence (masked):          Is dit fascisme? Het is de vraag die telkens terugkomt. Baudets opmerking over homeopathische verdunning: is dit fascisme? De bestorming van het Capitool: is dit fascisme? <extra_id_0> -lhbti-activisten: <extra_id_1> fascisme?
# Final model output sequence:      Is dit fascisme? Het is de vraag die telkens terugkomt. Baudets opmerking over homeopathische verdunning: is dit fascisme? De bestorming van het Capitool: is dit fascisme? De acties van anti -lhbti-activisten: is dit fascisme?
# Input sequence (ground truth):    Is dit fascisme? Het is de vraag die telkens terugkomt. Baudets opmerking over homeopathische verdunning: is dit fascisme? De bestorming van het Capitool: is dit fascisme? Poetins strijd tegen -lhbti-activisten: is dit fascisme?
# Masked tokens:                    ['Poetins strijd tegen', 'is dit']
# Filled tokens:                    ['De acties van anti', 'is dit']
# Levenshtein distance (avg):       0.42
#
# seq 16
# ['De', 'discotheek', 'is', 'aan', 'het', 'verdwijnen', 'in', 'Itali.', 'Van', 'de', 'ruim', 'zevenduizend', 'danspaleizen', 'die', 'eind', 'jaren', '<extra_id_0>', 'land', 'stonden,', 'is', 'nog', 'maar', 'de', 'helft', 'over.', 'De', 'rest', 'is', 'vervallen,', 'verlaten', 'of', 'omgebouwd', 'tot', '<extra_id_1>']
# ['<pad>', '<extra_id_0>', "'90", 'in', 'het', '<extra_id_1>', 'clubs.</s>']
# Sequence id:                      seq16-0
# Input sequence (masked):          De discotheek is aan het verdwijnen in Itali. Van de ruim zevenduizend danspaleizen die eind jaren <extra_id_0> land stonden, is nog maar de helft over. De rest is vervallen, verlaten of omgebouwd tot <extra_id_1>
# Final model output sequence:      De discotheek is aan het verdwijnen in Itali. Van de ruim zevenduizend danspaleizen die eind jaren '90 in het land stonden, is nog maar de helft over. De rest is vervallen, verlaten of omgebouwd tot clubs.
# Input sequence (ground truth):    De discotheek is aan het verdwijnen in Itali. Van de ruim zevenduizend danspaleizen die eind jaren 90 in het land stonden, is nog maar de helft over. De rest is vervallen, verlaten of omgebouwd tot supermarkt of kantoor.
# Masked tokens:                    ['90 in het', 'supermarkt of kantoor.']
# Filled tokens:                    ["'90 in het", 'clubs.']
# Levenshtein distance (avg):       0.53
#
# seq 17
# ['De', 'totale', 'waarde', 'van', '<extra_id_0>', 'in', 'Holland-producten', 'is', 'vorig', 'jaar', 'met', 'ruim', '5', '<extra_id_1>', 'opzichte', 'van', '2022.', 'Er', 'werd', 'voor', '19', 'miljard', 'euro', 'minder', 'aan', 'Nederlandse', 'producten', 'uitgevoerd', 'dan', 'een', 'jaar', 'eerder,', 'meldt', 'het', 'Centraal', 'Bureau', 'voor', 'de', 'Statistiek', '(CBS).']
# ['<pad>', '<extra_id_0>', 'de', 'handel', '<extra_id_1>', 'procent', 'gedaald', 'ten', '<extra_id_2>', 'verloren', 'ten', '<extra_id_3>', 'de', 'handel', '<extra_id_4>', 'procent', 'gedaald', 'ten', '<extra_id_2>t', 'ten', '<extra_id_2>.', 'Ten', 'opzichte', 'van', 'het', 'jaar', 'ervoor', 'ten', '<extra_id_2>t', 'ten', '<extra_id_3>', 'de', 'handel', '<extra_id_4>', 'procent', 'gedaald', 'ten', '<extra_id_2>t', 'ten', '<extra_id_2>', 'ten', '<extra_id_2>', 'ten', '<extra_id_16>', 'de', 'handel', '<extra_id_17>', 'de', 'handel', '<extra_id_18>t', '<extra_id_19>', 'gedaald', 'ten', '<extra_id_22>t.', 'Investeren', '<extra_id_23>t', '<extra_id_18>.', 'Investeren', '<extra_id_19>t', 'ten', 'opzichte', 'van', '2022', '<extra_id_24>t', 'ten', 'opzichte', 'van', '2022', '<extra_id_25>', 'de', 'handel', '<extra_id_26>', 'procent', 'gedaald', 'ten', '<extra_id_27>', 'gedaald', 'ten', '<extra_id_28>', 'procent', 'gedaald', 'ten', '<extra_id_29>', 'de', 'handel', '<extra_id_33>den', 'ten', 'opzichte', 'van', '2022', 'ten', '<extra_id_29>t', 'ten', 'opzichte', 'van', '2022.', 'Ten', 'opzichte', 'van', '2022', 'ten', '<extra_id_29>t', 'ten', 'opzichte', 'van', '2022.', 'Ten', 'op', '<extra_id_29>t', 'ten', '<extra_id_30>t', 'ten', 'onrechte', 'ten', '<extra_id_34>', 'procent', 'gedaald', 'ten', '<extra_id_35>t', 'ten', '<extra_id_36>t', 'ten', '<extra_id_37>t', '<extra_id_38>t', '<extra_id_39>t', 'ten', '<extra_id_40>', 'de', 'handel', '<extra_id_41>t', 'ten', '<extra_id_49>', 'procent', 'gedaald', 'ten', '<extra_id_50>t', 'ten', '<extra_id_51>t', 'ten', 'opzichte', 'van', '2022.', 'Investeren', '<extra_id_41>t', 'ten', 'opzichte', 'van', '2022', 'Investeren', 'in', 'Holland', '<extra_id_52>t', 'ten', '<extra_id_53>', 'de', 'handel', 'in', 'Made', '<extra_id_26>', 'procent', '<extra_id_54>', 'ten', '<extra_id_55>', 'ten', '<extra_id_56></s>']
# Sequence id:                      seq17-0
# Input sequence (masked):          De totale waarde van <extra_id_0> in Holland-producten is vorig jaar met ruim 5 <extra_id_1> opzichte van 2022. Er werd voor 19 miljard euro minder aan Nederlandse producten uitgevoerd dan een jaar eerder, meldt het Centraal Bureau voor de Statistiek (CBS).
# Final model output sequence:      De totale waarde van de handel in Holland-producten is vorig jaar met ruim 5 procent gedaald ten opzichte van 2022. Er werd voor 19 miljard euro minder aan Nederlandse producten uitgevoerd dan een jaar eerder, meldt het Centraal Bureau voor de Statistiek (CBS).
# Input sequence (ground truth):    De totale waarde van de export van Made in Holland-producten is vorig jaar met ruim 5 procent gedaald ten opzichte van 2022. Er werd voor 19 miljard euro minder aan Nederlandse producten uitgevoerd dan een jaar eerder, meldt het Centraal Bureau voor de Statistiek (CBS).
# Masked tokens:                    ['de export van Made', 'procent gedaald ten']
# Filled tokens:                    ['de handel', 'procent gedaald ten']
# Levenshtein distance (avg):       0.33
#
# seq 18
# ['Schrijven', 'betaalt', 'de', 'hypotheek', 'niet,', 'daarom', 'is', 'Walter', '<extra_id_0>', 'ook', 'Salesforce', 'Marketing', 'Cloud', 'Developer', 'een', 'bullshitbaan?']
# ['<pad><extra_id_0>', 'Schrijver', '<extra_id_1>', 'Schrijver', '<extra_id_2>', 'Schrijver', '<extra_id_3>', 'Schrijver', '<extra_id_1>', 'Schrijver', '<extra_id_2>', 'Schrijver', '<extra_id_3>', 'Schrijver', '<extra_id_4>', 'Schrijver', 'ook', 'schrijver', 'van', 'een', 'boek.', 'Is', 'een', 'Salesforce', 'Marketing', 'Cloud', 'Developer', 'een', 'bullshitbaan?', 'Is', 'een', 'Salesforce', 'Marketing', 'Cloud', 'Developer', 'een', 'bullshitbaan?', 'Is', 'een', 'Salesforce', 'Marketing', 'Cloud', 'Developer', 'een', '<extra_id_11>?', 'Is', 'een', 'Salesforce', 'Marketing', 'Cloud', 'Developer', 'een', 'bullshitbaan?', 'Is', 'een', 'Salesforce', 'Marketing', 'Cloud', 'Developer', 'een', '<extra_id_12>', 'Schrijver', '<extra_id_13>', 'Schrijver', '<extra_id_1>', 'Schrijver', '<extra_id_1>', 'Schrijver', '<extra_id_15>', 'Schrijver', '<extra_id_16>', 'Schrijver', '<extra_id_17>', 'Schrijver', '<extra_id_18>', 'Schrijver', '<extra_id_19>', 'Schrijver', 'ook', 'Schrijver', 'is', 'ook', 'Schrijver', 'ook', 'Schrijver', '<extra_id_20>', 'Schrijver']
# Sequence id:                      seq18-0
# Input sequence (masked):          Schrijven betaalt de hypotheek niet, daarom is Walter <extra_id_0> ook Salesforce Marketing Cloud Developer een bullshitbaan?
# Final model output sequence:      Schrijven betaalt de hypotheek niet, daarom is Walter Schrijver ook Salesforce Marketing Cloud Developer een bullshitbaan?
# Input sequence (ground truth):    Schrijven betaalt de hypotheek niet, daarom is Walter van den Berg ook Salesforce Marketing Cloud Developer  een bullshitbaan?
# Masked tokens:                    ['van den Berg']
# Filled tokens:                    ['Schrijver']
# Levenshtein distance (avg):       0.83
#
# seq 19
# ['Miljoenen', 'Afghanen', 'leven', 'onder', 'de', 'armoedegrens.', 'Buitenlandse', 'donoren', 'bieden', 'weinig', 'hulp', 'omdat', 'de', 'Taliban', 'vrouwenrechten', 'drastisch', 'beperkten.', 'Vermindering', 'van', 'de', 'internationale', 'hulp', 'zal', 'dezelfde', 'Afghaanse', 'vrouwen', 'die', 'we', 'hopen', 'te', '<extra_id_0>', 'maar', '<extra_id_1>']
# ['<pad>', '<extra_id_0>', 'helpen,', '<extra_id_1>', 'niet', 'helpen.</s>']
# Sequence id:                      seq19-0
# Input sequence (masked):          Miljoenen Afghanen leven onder de armoedegrens. Buitenlandse donoren bieden weinig hulp omdat de Taliban vrouwenrechten drastisch beperkten. Vermindering van de internationale hulp zal dezelfde Afghaanse vrouwen die we hopen te <extra_id_0> maar <extra_id_1>
# Final model output sequence:      Miljoenen Afghanen leven onder de armoedegrens. Buitenlandse donoren bieden weinig hulp omdat de Taliban vrouwenrechten drastisch beperkten. Vermindering van de internationale hulp zal dezelfde Afghaanse vrouwen die we hopen te helpen, maar niet helpen.
# Input sequence (ground truth):    Miljoenen Afghanen leven onder de armoedegrens. Buitenlandse donoren bieden weinig hulp omdat de Taliban vrouwenrechten drastisch beperkten. Vermindering van de internationale hulp zal dezelfde Afghaanse vrouwen die we hopen te steunen alleen maar meer laten lijden.
# ...
# Input sequence (ground truth):    Is dit fascisme? Het is de vraag die telkens terugkomt. Baudets opmerking over homeopathische verdunning: is dit fascisme? De bestorming van het Capitool: is dit fascisme? Poetins strijd tegen -lhbti-activisten: is dit fascisme?
# Masked tokens:                    ['Baudets opmerking over', 'fascisme? De']
# Filled tokens:                    ['De', 'fascisme? De']
# Levenshtein distance (avg):       0.48
#
# seq 93
# ['De', 'rectores', 'magnifici', 'van', 'vijftien', 'Nederlandse', 'universiteiten', 'schrijven', 'de', 'banden', 'met', 'Isralische', 'universiteiten', '<extra_id_0>', 'Op', 'die', 'manier', 'kan', 'de', 'dialoog', 'met', 'de', 'partners', 'in', 'Isral', 'beter', 'gevoerd', 'worden,', 'ook', 'als', 'dat', 'schuurt', 'met', 'onze', '<extra_id_1>', 'overtuiging,', 'schrijven', 'ze', 'in', 'een', 'open', 'brief.']
# ['<pad>', '<extra_id_0>', 'op.', '<extra_id_1>', 'eigen', '<extra_id_2>.', '<extra_id_3>', 'sterker', 'te', 'maken.', '<extra_id_14>', 'eigen', '<extra_id_2>.', '<extra_id_1>', 'eigen', '<extra_id_2>.', 'Dat', 'is', 'hun', '<extra_id_2>.', '<extra_id_17>', 'sterker', 'te', 'maken.', '<extra_id_18>.', '<extra_id_7>.nl.', '<extra_id_13>', 'sterker', 'te', 'maken.', '<extra_id_17>', 'sterker', 'te', 'maken.', '<extra_id_18>.nl.', '<extra_id_13>', 'sterker', 'te', 'maken.', '<extra_id_17>', 'sterker', 'te', 'maken.', '<extra_id_18>.nl.', '<extra_id_13>', 'sterker', 'te', 'maken.', '<extra_id_17>', 'sterker', 'te', 'maken.', '<extra_id_18>.nl.', '<extra_id_19>.nl.', 'De', 'rectores', 'magnifici', '<extra_id_20>', 'eigen', '<extra_id_21>', 'eigen', '<extra_id_22>.', '<extra_id_23>.nl.', '<extra_id_18>.nl.', '<extra_id_26>', 'eigen', '<extra_id_27>.', '<extra_id_28>', 'eigen', '<extra_id_29>.', '<extra_id_33>.nl.', 'De', 'rectores', 'magnifici', 'hebben', 'een', 'sterke', 'wetenschappelijke', '<extra_id_22>.', '<extra_id_23>.nl.', '<extra_id_33>.nl.', 'De', '<extra_id_51>.nl.', '<extra_id_14>', 'eigen', 'wetenschappelijke', 'overtuiging.', '<extra_id_14>', 'eigen', '<extra_id_11>', 'eigen', '<extra_id_2>.nl.', '<extra_id_14>', 'eigen', '<extra_id_2>.nl.', '<extra_id_14>', 'eigen', '<extra_id_2>.', '<extra_id_54>', 'eigen', '<extra_id_55>.nl.', '<extra_id_1>', 'eigen', '<extra_id_16>', 'sterker', 'te', 'maken.', '<extra_id_56>', 'eigen', '<extra_id_2>.', '<extra_id_54>', 'eigen', '<extra_id_55>.nl</s>']
# Sequence id:                      seq93-0
# Input sequence (masked):          De rectores magnifici van vijftien Nederlandse universiteiten schrijven de banden met Isralische universiteiten <extra_id_0> Op die manier kan de dialoog met de partners in Isral beter gevoerd worden, ook als dat schuurt met onze <extra_id_1> overtuiging, schrijven ze in een open brief.
# Final model output sequence:      De rectores magnifici van vijftien Nederlandse universiteiten schrijven de banden met Isralische universiteiten op. Op die manier kan de dialoog met de partners in Isral beter gevoerd worden, ook als dat schuurt met onze eigen overtuiging, schrijven ze in een open brief.
# Input sequence (ground truth):    De rectores magnifici van vijftien Nederlandse universiteiten schrijven de banden met Isralische universiteiten niet te willen verbreken. Op die manier kan de dialoog met de partners in Isral beter gevoerd worden, ook als dat schuurt met onze en andermans diepste overtuiging, schrijven ze in een open brief.
# Masked tokens:                    ['niet te willen verbreken.', 'en andermans diepste']
# Filled tokens:                    ['op.', 'eigen']
# Levenshtein distance (avg):       0.91
#
# seq 94
# ['Met', 'AI', 'Overview,', 'een', 'nieuwe', 'manier', 'van', 'Google', 'om', 'te', 'zoeken,', 'zouden', 'consumenten', 'kwalitatief', 'hoogwaardige', 'antwoorden', '<extra_id_0>', 'krijgen.', 'Maar', 'de', 'zoekmachine', 'blijkt', 'soms', 'verbijsterende', 'blunders', 'te', 'maken.']
# ['<pad>', '<extra_id_0>', 'op', 'hun', 'vragen', '<extra_id_1>', 'op', 'hun', 'vragen', '<extra_id_2>', 'krijgen.', 'Google', 'maakt', 'nieuwe', 'foutmeldingen', '<extra_id_3>', 'op', 'hun', 'vragen', '<extra_id_4>', 'krijgen.', 'Google', 'maakt', 'nieuwe', 'foutmeldingen', 'Google', 'maakt', 'nieuwe', 'foutmeldingen', '<extra_id_5>', 'te', 'zien', '<extra_id_1>', 'te', '<extra_id_15>.</s>']
# Sequence id:                      seq94-0
# Input sequence (masked):          Met AI Overview, een nieuwe manier van Google om te zoeken, zouden consumenten kwalitatief hoogwaardige antwoorden <extra_id_0> krijgen. Maar de zoekmachine blijkt soms verbijsterende blunders te maken.
# Final model output sequence:      Met AI Overview, een nieuwe manier van Google om te zoeken, zouden consumenten kwalitatief hoogwaardige antwoorden op hun vragen krijgen. Maar de zoekmachine blijkt soms verbijsterende blunders te maken.
# Input sequence (ground truth):    Met AI Overview, een nieuwe manier van Google om te zoeken, zouden consumenten kwalitatief hoogwaardige antwoorden op hun vragen moeten krijgen. Maar de zoekmachine blijkt soms verbijsterende blunders te maken.
# Masked tokens:                    ['op hun vragen moeten']
# Filled tokens:                    ['op hun vragen']
# Levenshtein distance (avg):       0.35
#
# seq 95
# ['Zelden', 'won', 'een', 'renner', 'een', '<extra_id_0>', 'grote', 'rondes', 'met', 'zo', 'veel', 'overmacht', 'als', '<extra_id_1>', 'dItalia', 'van', '2024.', 'Dat', 'is', 'grotendeels', 'zijn', 'verdienste,', 'maar', 'de', 'Sloveen', 'trof', 'ook', 'tegenstanders', 'die', 'al', 'in', 'de', 'tweede', 'etappe', 'het', 'hoofd', 'in', 'de', 'schoot', 'legden.']
# ['<pad>', '<extra_id_0>', 'etappe', 'in', '<extra_id_1>', 'de', 'Giro', '<extra_id_2>', 'het', 'Giro', '<extra_id_2>', 'het', 'Giro', '<extra_id_3>', 'etappe', 'in', 'de', 'eerste', 'etappe', 'van', 'de', 'eerste', 'etappe', 'van', 'de', 'eerste', 'ronde', 'van', 'de', 'eerste', 'ronde', 'van', 'de', 'eerste', 'ronde', 'van', 'de', 'Giro', '<extra_id_2>', 'Giro', '<extra_id_16>', 'etappe', 'in', '<extra_id_17>', 'van', 'de', 'eerste', '<extra_id_18>.', 'Giro', '<extra_id_19>', 'Giro', '<extra_id_22>', 'Giro', '<extra_id_23>', 'Giro', '<extra_id_5>', 'van', 'de', '<extra_id_54>', 'het', 'Giro', '<extra_id_55>', 'in', '<extra_id_17>', 'van', 'de', 'eerste', '<extra_id_17>', 'van', 'de', 'eerste', '<extra_id_17>', 'van', 'de', 'eerste', '<extra_id_17>', 'van', 'de', 'eerste', '<extra_id_17>', 'van', 'de', 'eerste', '<extra_id_18>.', 'In', 'de', 'eerste', '<extra_id_56></s>']
# Sequence id:                      seq95-0
# Input sequence (masked):          Zelden won een renner een <extra_id_0> grote rondes met zo veel overmacht als <extra_id_1> dItalia van 2024. Dat is grotendeels zijn verdienste, maar de Sloveen trof ook tegenstanders die al in de tweede etappe het hoofd in de schoot legden.
# Final model output sequence:      Zelden won een renner een etappe in grote rondes met zo veel overmacht als de Giro dItalia van 2024. Dat is grotendeels zijn verdienste, maar de Sloveen trof ook tegenstanders die al in de tweede etappe het hoofd in de schoot legden.
# Input sequence (ground truth):    Zelden won een renner een van de drie grote rondes met zo veel overmacht als Tadej Pogacar de Giro dItalia van 2024. Dat is grotendeels zijn verdienste, maar de Sloveen trof ook tegenstanders die al in de tweede etappe het hoofd in de schoot legden.
# Masked tokens:                    ['van de drie', 'Tadej Pogacar de Giro']
# Filled tokens:                    ['etappe in', 'de Giro']
# Levenshtein distance (avg):       0.7
#
# seq 96
# ['<extra_id_0>', 'televisie', 'bekende', 'Henritte', 'Momma', 'is', 'eind', 'vorige', 'maand', 'op', '90-jarige', 'leeftijd', 'overleden.', 'Miljoenen', 'Nederlanders', 'leerden', '<extra_id_1>', 'jaren', 'kennen', 'als', 'de', 'liefdevolle', 'en', 'zorgzame', 'moeder', 'van', 'de', 'autistische', 'kunstenaar', 'Kees', 'Momma.']
# ['<pad>', '<extra_id_0>.', 'De', 'op', '<extra_id_1>', 'haar', 'de', 'afgelopen', '<extra_id_2>', 'haar', 'als', 'Henriette', 'Momma.', 'De', 'op', 'televisie', 'bekende', 'Henritte', 'Momma', 'kwam', 'in', 'de', 'jaren', 'tachtig', 'van', 'de', '<extra_id_2>.', 'De', 'op', '<extra_id_3>', 'en', 'op', '<extra_id_1>', 'haar', 'de', 'afgelopen', '<extra_id_2>', 'al', '<extra_id_2>', 'haar', 'al', '<extra_id_2>.', 'De', 'op', '<extra_id_16>e', 'en', 'op', '<extra_id_1>', 'haar', '<extra_id_2>', 'haar', 'op', '<extra_id_1>', 'haar', 'de', 'afgelopen', '<extra_id_15>', 'haar', 'de', 'afgelopen', '<extra_id_16>e', 'en', 'op', '<extra_id_17>e', 'en', 'op', '<extra_id_1>', 'haar', 'de', 'afgelopen', 'jaren', 'op', '<extra_id_1>', 'haar', 'de', 'afgelopen', '<extra_id_2>', 'vele', '<extra_id_16>e', 'en', 'op', '<extra_id_17>e', 'en', 'op', '<extra_id_18>.', 'De', 'op', '<extra_id_19>e', '<extra_id_22>e', '<extra_id_23>e', '<extra_id_24>e', '<extra_id_25>', 'en', 'op', '<extra_id_26>', 'haar', 'de', 'afgelopen', '<extra_id_27>e', '<extra_id_28>', 'haar', 'de', 'afgelopen', '<extra_id_11>', 'haar', 'de', 'afgelopen', '<extra_id_2>', 'vele', '<extra_id_2>.', 'De', '<extra_id_2>', 'op', 'de', '<extra_id_27>e', 'en', 'op', '<extra_id_45>e', '<extra_id_11>', 'haar', 'de', 'afgelopen', '<extra_id_11>', 'haar', 'de', 'afgelopen', '<extra_id_11>', 'haar', 'de', '<extra_id_2>.', 'De', '<extra_id_11>', 'haar', 'de', '<extra_id_2>', 'op', '<extra_id_22>e', '<extra_id_4>', 'haar', '<extra_id_5>', 'op', '<extra_id_5>', 'op', '<extra_id_5>', 'op', '<extra_id_2>.', 'De', 'op', '<extra_id_5>', 'op', '<extra_id_2>', 'op', '<extra_id_2>', 'op', '<extra_id_2>', 'op', '<extra_id_2>', 'op', '<extra_id_2>', 'en', 'al', '<extra_id_50>', 'haar', '<extra_id_22>', 'de', '<extra_id_23>e', '<extra_id_54>', 'haar', 'de', 'afgelopen', '<extra_id_12>', 'op', '<extra_id_55>e', 'op', 'televisie.', 'De', 'op', '<extra_id_1>', 'haar', '<extra_id_56>', 'haar', 'de', 'afge</s>']
# Sequence id:                      seq96-0
# Input sequence (masked):          <extra_id_0> televisie bekende Henritte Momma is eind vorige maand op 90-jarige leeftijd overleden. Miljoenen Nederlanders leerden <extra_id_1> jaren kennen als de liefdevolle en zorgzame moeder van de autistische kunstenaar Kees Momma.
# Final model output sequence:      De op televisie bekende Henritte Momma is eind vorige maand op 90-jarige leeftijd overleden. Miljoenen Nederlanders leerden haar de afgelopen jaren kennen als de liefdevolle en zorgzame moeder van de autistische kunstenaar Kees Momma.
# Input sequence (ground truth):    De van televisie bekende Henritte Momma is eind vorige maand op 90-jarige leeftijd overleden. Miljoenen Nederlanders leerden haar de afgelopen jaren kennen als de liefdevolle en zorgzame moeder van de autistische kunstenaar Kees Momma.
# Masked tokens:                    ['De van', 'haar de afgelopen']
# Filled tokens:                    ['De op', 'haar de afgelopen']
# Levenshtein distance (avg):       0.25
#
# seq 97
# ['De', 'laatste', 'verkeerstuin', 'van', 'Nederland', 'in', 'zijn', 'soort', 'dreigt', 'te', 'verdwijnen', 'nu', 'de', 'gemeente', 'Utrecht', 'de', '<extra_id_0>', 'zonde,', 'vinden', 'de', 'vrijwilligers.']
# ['<pad>', '<extra_id_0>', 'plannen', 'wil', 'aanpassen.', 'Een', '<extra_id_1>', 'besluit.', 'Een', '<extra_id_15>.', 'Een', '<extra_id_16>', 'plannen', 'wil', 'aanpassen.', 'Een', '<extra_id_1>', 'wil.', 'Een', '<extra_id_1>.', 'Een', '<extra_id_15>.', 'Een', '<extra_id_16>', 'plannen', 'wil', 'aanpassen.', 'Een', '<extra_id_17>', 'plannen', 'wil', 'aanpassen.', 'Een', '<extra_id_18>.', 'Een', '<extra_id_19>.', '<extra_id_20>.', 'Een', '<extra_id_21>.', '<extra_id_22>.', 'Een', '<extra_id_23>.', 'Een', '<extra_id_24>.', 'Een', '<extra_id_25>', 'plannen', 'wil', 'aanpassen.', 'Een', '<extra_id_26>t.', 'Een', '<extra_id_27>.', 'Een', '<extra_id_28>.', 'Een', '<extra_id_29>.', 'Een', '<extra_id_30>.', 'Een', '<extra_id_31>.', 'Een', '<extra_id_32>.', 'Een', '<extra_id_26>.', 'Een', '<extra_id_26>.</s>']
# Sequence id:                      seq97-0
# Input sequence (masked):          De laatste verkeerstuin van Nederland in zijn soort dreigt te verdwijnen nu de gemeente Utrecht de <extra_id_0> zonde, vinden de vrijwilligers.
# Final model output sequence:      De laatste verkeerstuin van Nederland in zijn soort dreigt te verdwijnen nu de gemeente Utrecht de plannen wil aanpassen. Een zonde, vinden de vrijwilligers.
# Input sequence (ground truth):    De laatste verkeerstuin van Nederland in zijn soort dreigt te verdwijnen nu de gemeente Utrecht de subsidie stopzet. Eeuwig zonde, vinden de vrijwilligers.
# Masked tokens:                    ['subsidie stopzet. Eeuwig']
# Filled tokens:                    ['plannen wil aanpassen. Een']
# Levenshtein distance (avg):       0.81
#
# seq 98
# ['Nog', 'nooit', 'kregen', '<extra_id_0>', 'borstvoeding.', 'Er', 'wordt', 'te', 'weinig', 'ruimte', 'voor', 'gegeven,', 'zeggen', 'jonge', 'moeders', 'in', 'Lelystad.']
# ['<pad><extra_id_0>', 'ze', '<extra_id_1>', 'ze', '<extra_id_2>', 'ze', 'borstvoeding.', '<extra_id_3>', 'ze', 'nog', 'geen', '<extra_id_14>', 'ze', '<extra_id_1>', 'ze', '<extra_id_15>', 'ze', 'borstvoeding.', 'De', 'ouders', 'krijgen', 'te', 'weinig', 'ruimte', 'voor', '<extra_id_16>', 'ze', '<extra_id_17>', 'ze', '<extra_id_1>', 'ze', '<extra_id_18>', 'ze', 'borstvoeding.', '<extra_id_19>', 'ze', 'nog', 'geen', 'borstvoeding.', '<extra_id_20>', 'ze', 'nog', '<extra_id_21>', 'ze', 'nog', 'borstvoeding.', '<extra_id_22>', 'ze', 'nog', 'geen', 'borstvoeding.', '<extra_id_23>', 'ze', 'nog', '<extra_id_24>', 'ze', 'nog', '<extra_id_25>', 'ze', '<extra_id_26>', 'ze', 'nog', '<extra_id_15>', 'ze', 'nog', '<extra_id_15>', 'ze', 'nog', '<extra_id_16>', 'ze', 'nog', '<extra_id_17>', 'ze', 'nog', '<extra_id_18>', 'ze', 'nog', '<extra_id_26>', 'ze', 'nog', '<extra_id_27>', 'ze', 'nog', '<extra_id_28>', 'ze', 'nog', 'borstvoeding.', 'De', 'ouders', 'krijgen', 'te', 'weinig', 'ruimte', 'voor', '<extra_id_29>']
# Sequence id:                      seq98-0
# Input sequence (masked):          Nog nooit kregen <extra_id_0> borstvoeding. Er wordt te weinig ruimte voor gegeven, zeggen jonge moeders in Lelystad.
# Final model output sequence:      Nog nooit kregen ze borstvoeding. Er wordt te weinig ruimte voor gegeven, zeggen jonge moeders in Lelystad.
# Input sequence (ground truth):    Nog nooit kregen zo weinig babys borstvoeding. Er wordt te weinig ruimte voor gegeven, zeggen jonge moeders in Lelystad.
# Masked tokens:                    ['zo weinig babys']
# Filled tokens:                    ['ze']
# Levenshtein distance (avg):       0.87
#
# seq 99
# ['Londen', 'is', 'onvoldoende', 'voorbereid', 'op', 'de', 'gevolgen', 'van', 'klimaatverandering.', 'Zo', 'moet', 'de', 'waterkering', 'Thames', 'Barrier,', 'die', 'veel', 'meer', '<extra_id_0>', 'eerder', 'worden', 'vervangen.']
# ['<pad>', '<extra_id_0>', 'water', 'verbruikt,', '<extra_id_1>', 'al', 'veel', '<extra_id_15>', 'moet', 'worden', 'vervangen.', 'De', 'waterkering', '<extra_id_16>', 'water', 'verbruikt,', '<extra_id_1>', 'al', 'veel', '<extra_id_15>,', 'al', 'veel', '<extra_id_16>', 'water', 'verbruikt,', 'al', 'veel', '<extra_id_17>', 'water', 'verbruikt,', '<extra_id_18>', 'worden.', '<extra_id_19>.', '<extra_id_20>', 'al', '<extra_id_43>', 'water', 'verbruikt,', 'al', 'veel', '<extra_id_18>.', '<extra_id_44>.', '<extra_id_54>凇</s>']
# Sequence id:                      seq99-0
# Input sequence (masked):          Londen is onvoldoende voorbereid op de gevolgen van klimaatverandering. Zo moet de waterkering Thames Barrier, die veel meer <extra_id_0> eerder worden vervangen.
# Final model output sequence:      Londen is onvoldoende voorbereid op de gevolgen van klimaatverandering. Zo moet de waterkering Thames Barrier, die veel meer water verbruikt, eerder worden vervangen.
# Input sequence (ground truth):    Londen is onvoldoende voorbereid op de gevolgen van klimaatverandering. Zo moet de waterkering Thames Barrier, die veel meer gebruikt wordt dan gedacht, eerder worden vervangen.
# Masked tokens:                    ['gebruikt wordt dan gedacht,']
# Filled tokens:                    ['water verbruikt,']
# Levenshtein distance (avg):       0.81

# %%
results_df
# Out:
#    Sequence id Model size                      Input sequence (ground truth)  \
# 0       seq0-0      large  Met een spectaculaire reddingsoperatie wist he...
# 1       seq1-0      large  Met een spectaculaire reddingsoperatie wist he...
# 2       seq2-0      large  Op 1 juni begint de Nederlander Hermen Hulst a...
# 3       seq3-0      large  De liberaal-conservatieve Nieuw-Vlaamse Allian...
# 4       seq4-0      large  De elfde editie van de Willem IV Rally was een...
# ..         ...        ...                                                ...
# 95     seq95-0      large  Zelden won een renner een van de drie grote ro...
# 96     seq96-0      large  De van televisie bekende Henritte Momma is ein...
# 97     seq97-0      large  De laatste verkeerstuin van Nederland in zijn ...
# 98     seq98-0      large  Nog nooit kregen zo weinig babys borstvoeding....
# 99     seq99-0      large  Londen is onvoldoende voorbereid op de gevolge...
#
#                               Input sequence (masked)  \
# 0   Met een spectaculaire reddingsoperatie wist he...
# 1   <extra_id_0> reddingsoperatie wist het Isralis...
# 2   Op 1 juni begint de Nederlander Hermen Hulst a...
# 3   De liberaal-conservatieve <extra_id_0> blijft ...
# 4   De <extra_id_0> de Willem IV Rally was een gro...
# ..                                                ...
# 95  Zelden won een renner een <extra_id_0> grote r...
# 96  <extra_id_0> televisie bekende Henritte Momma ...
# 97  De laatste verkeerstuin van Nederland in zijn ...
# 98  Nog nooit kregen <extra_id_0> borstvoeding. Er...
# 99  Londen is onvoldoende voorbereid op de gevolge...
#
#                                 Model output sequence  \
# 0   Met een spectaculaire reddingsoperatie wist he...
# 1   In een reddingsoperatie wist het Isralische le...
# 2   Op 1 juni begint de Nederlander Hermen Hulst a...
# 3   De liberaal-conservatieve Partij voor de Vrijh...
# 4   De eerste editie van de Willem IV Rally was ee...
# ..                                                ...
# 95  Zelden won een renner een etappe in grote rond...
# 96  De op televisie bekende Henritte Momma is eind...
# 97  De laatste verkeerstuin van Nederland in zijn ...
# 98  Nog nooit kregen ze borstvoeding. Er wordt te ...
# 99  Londen is onvoldoende voorbereid op de gevolge...
#
#                                         Masked tokens  \
# 0                 [actie voor de, 120 gijzelaars die]
# 1      [Met een spectaculaire, prijs aan Palestijnse]
# 2   [van Sony Interactive, gamebedrijf door een tu...
# 3   [Nieuw-Vlaamse Alliantie (N-VA), de regionale ...
# 4         [elfde editie van, van de organisatie. Dit]
# ..                                                ...
# 95               [van de drie, Tadej Pogacar de Giro]
# 96                        [De van, haar de afgelopen]
# 97                         [subsidie stopzet. Eeuwig]
# 98                                  [zo weinig babys]
# 99                      [gebruikt wordt dan gedacht,]
#
#                                         Filled tokens  \
# 0               [prijs voor, 200.000 Palestijnen die]
# 1                  [In een, spanning aan Israëlische]
# 2                [van Sony Computer, speler van zijn]
# 3   [Partij voor de Vrijheid, de regionale verkiez...
# 4                            [eerste editie van, Dit]
# ..                                                ...
# 95                               [etappe in, de Giro]
# 96                         [De op, haar de afgelopen]
# 97                       [plannen wil aanpassen. Een]
# 98                                               [ze]
# 99                                 [water verbruikt,]
#
#     Number of masked tokens  Masking percentage  Duplicate count  \
# 0                         6                  15                1
# 1                         6                  15                1
# 2                         7                  15                1
# 3                         6                  15                1
# 4                         7                  15                1
# ..                      ...                 ...              ...
# 95                        7                  15                1
# 96                        5                  15                1
# 97                        3                  15                1
# 98                        3                  15                1
# 99                        4                  15                1
#
#                         Levenshtein distances  Levenshtein distance (avg)
# 0    [0.6153846153846154, 0.6956521739130435]                        0.66
# 1                 [0.8095238095238095, 0.625]                        0.72
# 2                               [0.5, 0.8125]                        0.66
# 3                 [0.9, 0.038461538461538464]                        0.47
# 4   [0.23529411764705882, 0.8695652173913043]                        0.55
# ..                                        ...                         ...
# 95   [0.7272727272727273, 0.6666666666666666]                        0.70
# 96                                 [0.5, 0.0]                        0.25
# 97                       [0.8076923076923077]                        0.81
# 98                       [0.8666666666666667]                        0.87
# 99                       [0.8148148148148148]                        0.81
#
# [100 rows x 12 columns]

# %%
#results_df.to_csv(f"..\\results\\20240520\{TITLE}\\{mask_per}\\results_{TITLE}_{model_size}.csv", index=False)
results_df.to_csv(f"..\\results\\working_results\\mT5\\{TYPE}\\results_{mask_per}\\{TITLE}\\results_{TITLE}_{model_size}.csv", index=False)

# %% [markdown]
# **Sliding window**

# %%
# # Loop over sentences and fill_mask
# results_df = None
# for i in range(len(duplicates_groene)):

#   input_token_len = len(duplicates_groene.text[i].split())

#   # Skip is sequence is to short
#   if input_token_len < 10:
#     continue

#   # Sliding window start_index, n_masks
#   n_masks=3
#   for idx in range(input_token_len - n_masks):
#     print(f"Start index: {idx}")
#     # Generate results
#     results_df_temp = fill_mask(duplicates_groene.text[i], mask_start_index=idx, n_masks=n_masks, sequence_id=f"seq{i}")
#     # Add results to df
#     results_df = pd.concat([results_df, results_df_temp], ignore_index=True)

# %%
results_df
# Out:
#    Sequence id Model size                      Input sequence (ground truth)  \
# 0       seq0-0      large  Met een spectaculaire reddingsoperatie wist he...
# 1       seq1-0      large  Met een spectaculaire reddingsoperatie wist he...
# 2       seq2-0      large  Op 1 juni begint de Nederlander Hermen Hulst a...
# 3       seq3-0      large  De liberaal-conservatieve Nieuw-Vlaamse Allian...
# 4       seq4-0      large  De elfde editie van de Willem IV Rally was een...
# ..         ...        ...                                                ...
# 95     seq95-0      large  Zelden won een renner een van de drie grote ro...
# 96     seq96-0      large  De van televisie bekende Henritte Momma is ein...
# 97     seq97-0      large  De laatste verkeerstuin van Nederland in zijn ...
# 98     seq98-0      large  Nog nooit kregen zo weinig babys borstvoeding....
# 99     seq99-0      large  Londen is onvoldoende voorbereid op de gevolge...
#
#                               Input sequence (masked)  \
# 0   Met een spectaculaire reddingsoperatie wist he...
# 1   <extra_id_0> reddingsoperatie wist het Isralis...
# 2   Op 1 juni begint de Nederlander Hermen Hulst a...
# 3   De liberaal-conservatieve <extra_id_0> blijft ...
# 4   De <extra_id_0> de Willem IV Rally was een gro...
# ..                                                ...
# 95  Zelden won een renner een <extra_id_0> grote r...
# 96  <extra_id_0> televisie bekende Henritte Momma ...
# 97  De laatste verkeerstuin van Nederland in zijn ...
# 98  Nog nooit kregen <extra_id_0> borstvoeding. Er...
# 99  Londen is onvoldoende voorbereid op de gevolge...
#
#                                 Model output sequence  \
# 0   Met een spectaculaire reddingsoperatie wist he...
# 1   In een reddingsoperatie wist het Isralische le...
# 2   Op 1 juni begint de Nederlander Hermen Hulst a...
# 3   De liberaal-conservatieve Partij voor de Vrijh...
# 4   De eerste editie van de Willem IV Rally was ee...
# ..                                                ...
# 95  Zelden won een renner een etappe in grote rond...
# 96  De op televisie bekende Henritte Momma is eind...
# 97  De laatste verkeerstuin van Nederland in zijn ...
# 98  Nog nooit kregen ze borstvoeding. Er wordt te ...
# 99  Londen is onvoldoende voorbereid op de gevolge...
#
#                                         Masked tokens  \
# 0                 [actie voor de, 120 gijzelaars die]
# 1      [Met een spectaculaire, prijs aan Palestijnse]
# 2   [van Sony Interactive, gamebedrijf door een tu...
# 3   [Nieuw-Vlaamse Alliantie (N-VA), de regionale ...
# 4         [elfde editie van, van de organisatie. Dit]
# ..                                                ...
# 95               [van de drie, Tadej Pogacar de Giro]
# 96                        [De van, haar de afgelopen]
# 97                         [subsidie stopzet. Eeuwig]
# 98                                  [zo weinig babys]
# 99                      [gebruikt wordt dan gedacht,]
#
#                                         Filled tokens  \
# 0               [prijs voor, 200.000 Palestijnen die]
# 1                  [In een, spanning aan Israëlische]
# 2                [van Sony Computer, speler van zijn]
# 3   [Partij voor de Vrijheid, de regionale verkiez...
# 4                            [eerste editie van, Dit]
# ..                                                ...
# 95                               [etappe in, de Giro]
# 96                         [De op, haar de afgelopen]
# 97                       [plannen wil aanpassen. Een]
# 98                                               [ze]
# 99                                 [water verbruikt,]
#
#     Number of masked tokens  Masking percentage  Duplicate count  \
# 0                         6                  15                1
# 1                         6                  15                1
# 2                         7                  15                1
# 3                         6                  15                1
# 4                         7                  15                1
# ..                      ...                 ...              ...
# 95                        7                  15                1
# 96                        5                  15                1
# 97                        3                  15                1
# 98                        3                  15                1
# 99                        4                  15                1
#
#                         Levenshtein distances  Levenshtein distance (avg)
# 0    [0.6153846153846154, 0.6956521739130435]                        0.66
# 1                 [0.8095238095238095, 0.625]                        0.72
# 2                               [0.5, 0.8125]                        0.66
# 3                 [0.9, 0.038461538461538464]                        0.47
# 4   [0.23529411764705882, 0.8695652173913043]                        0.55
# ..                                        ...                         ...
# 95   [0.7272727272727273, 0.6666666666666666]                        0.70
# 96                                 [0.5, 0.0]                        0.25
# 97                       [0.8076923076923077]                        0.81
# 98                       [0.8666666666666667]                        0.87
# 99                       [0.8148148148148148]                        0.81
#
# [100 rows x 12 columns]

# %%
# from google.colab import files

# results_df.to_csv('results_df.csv')
# files.download('results_df.csv')
