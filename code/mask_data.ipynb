# %%
import pandas as pd
import random
import math

# %%
TITLE = 'nrc'
TYPE = 'baseline' # 'duplicates' 'unique'
MASK_PERC = 0.30
MASK_LEVEL_FOLDER = 'masked_input_30'

# %%
df = pd.read_csv(f"..\\data\\{TYPE}\\text_{TYPE}_{TITLE}.csv")

# Filter out rows with less than 20 characters in the 'text' column
data = df[df['text'].str.len() >= 20]

# Reindex the DataFrame
data = data.reset_index(drop=True)

# Display the first few rows of the filtered DataFrame
print(data.head())
# Out:
#    Unnamed: 0                                               text  text_count  \
# 0           2  Met een spectaculaire reddingsoperatie wist he...           1
# 1           6  Met een spectaculaire reddingsoperatie wist he...           1
# 2           7  Op 1 juni begint de Nederlander Hermen Hulst a...           1
# 3           9  De liberaal-conservatieve Nieuw-Vlaamse Allian...           1
# 4          14  De elfde editie van de Willem IV Rally was een...           1
#
#                                                 link paywall
# 0  Hoe vang je een planetoïde? China heeft groots...     ja
# 1  https://www.nrc.nl/nieuws/2024/05/24/follow-th...     ja
# 2       Borstvoeding geven is niet meer gewoon - NRC     ja
# 3  https://www.nrc.nl/nieuws/2024/05/31/trump-zaa...     ja
# 4  https://www.nrc.nl/nieuws/2024/05/29/zelfstand...     ja

# %%
import re
def clean_input(input_sequence):
    # Remove unknown characters using regex
    cleaned_sequence = re.sub(r'[^\x00-\x7F]+', '', input_sequence)
    return cleaned_sequence

# %%
# Combine tokens into final output sentence
def flatten(lst):
  flat_list = []
  for item in lst:
    if isinstance(item, list):
      flat_list.extend(flatten(item))
    else:
      flat_list.append(item)
  return flat_list

# %%
def find_valid_spans(input_tokens, span_lengths, gap=1, max_attempts=100):
    """
    Finds valid spans for masking in the input tokens while ensuring gaps between spans.

    Args:
    - input_tokens (list): List of input tokens.
    - span_lengths (list): List of lengths for each span.
    - gap (int): Minimum gap required between spans.
    - max_attempts (int): Maximum number of attempts to find valid spans.

    Returns:
    - list: Sorted list of indices for the valid spans.

    Raises:
    - ValueError: If valid spans cannot be found after the specified number of attempts.
    """
    
    for attempt in range(max_attempts):
        selected_indices = set()  # Set to store indices of selected spans
        used_indices = set()      # Set to store indices that are already used
        random.shuffle(span_lengths)  # Shuffle span lengths for variability
        potential_starts = list(range(len(input_tokens)))  # Potential start indices for spans
        random.shuffle(potential_starts)  # Shuffle start indices for randomness

        for span_length in span_lengths:
            found = False
            for start_index in potential_starts:
                # Ensure the span does not exceed the input length
                if start_index > len(input_tokens) - span_length:
                    continue

                # Define the range of the current span
                span_range = range(start_index, start_index + span_length)

                # Check if the span range and the adjacent indices are not used
                if all(idx not in used_indices for idx in span_range) and \
                   all(idx - 1 not in used_indices for idx in span_range) and \
                   all(idx + 1 not in used_indices for idx in span_range):
                    selected_indices.update(span_range)  # Add span indices to the set
                    used_indices.update(span_range)      # Mark these indices as used
                    potential_starts = [idx for idx in potential_starts if idx >= start_index + span_length + gap]
                    found = True
                    break

            if not found:
                break

        # Check if the total selected indices match the required span lengths
        if len(selected_indices) == sum(span_lengths):
            return sorted(list(selected_indices))

        # Relax the gap constraint after half the attempts
        if attempt == max_attempts // 2:
            gap = max(1, gap - 1)  # Reduce gap but not below 1

    raise ValueError("Failed to find non-overlapping spans with required gap after multiple attempts.")

# %%
def mask_input(input_data, mask_perc=0.15, noise_span_length=3):
    """
    Mask input text data by replacing a percentage of tokens with mask tags.

    Args:
    - input_data (object): Object containing input text data and additional information.
    - mask_perc (float): Percentage of tokens to mask. Default is 0.15 (15%).
    - noise_span_length (int): Desired average length of noise spans. Default is 3.

    Returns:
    - DataFrame: DataFrame containing masked sequences, masked tokens, and other information.
    """

    # Clean input text to ensure it doesn't contain unknown characters
    input_sequence = clean_input(input_data['text'])
    input_tokens = input_sequence.split()

    # Skip if sequence is too small
    if len(input_tokens) < 5:
        input_tokens = ""

    # Get the count of duplicate text (if any)
    duplicate_count = input_data['text_count']

    # Round number of masked tokens, at least 1 token masked
    n_masks = max(1, round(len(input_tokens) * mask_perc))

    try:
        if n_masks <= noise_span_length:
            span_lengths = [n_masks]
            n_noise_spans = 1
        else:
            n_noise_spans = int(round(n_masks / noise_span_length, 0))
            base_span_length = n_masks // n_noise_spans
            remaining_masks = n_masks % n_noise_spans

            # Initialize span lengths with the base span length
            span_lengths = [base_span_length] * n_noise_spans

            # Distribute remaining masks to achieve closer to the desired average span length
            for i in range(remaining_masks):
                span_lengths[i] += 1

        mask_tokens_indices = find_valid_spans(input_tokens, span_lengths)

        # Replace masked tokens with mask tags
        masked_input_tokens = []  # Full input tokens list containing masking tags
        masked_tokens = []        # List of masked tokens
        mask_id = 0
        i = 0
        while i < len(input_tokens):
            if i in mask_tokens_indices:
                # Find consecutive indices
                consecutive_indices = [i]
                while i + 1 < len(input_tokens) and i + 1 in mask_tokens_indices:
                    consecutive_indices.append(i + 1)
                    i += 1

                # Replace consecutive indices with a single mask token
                masked_input_tokens.append(f"<extra_id_{mask_id}>")
                masked_tokens.append([input_tokens[j] for j in consecutive_indices])
                mask_id += 1
                i += 1
            else:
                masked_input_tokens.append(input_tokens[i])
                i += 1

        n_masks_final = len(flatten(masked_tokens))

        # Verify if the final number of masked tokens matches the expected number
        if n_masks_final != n_masks:
            raise ValueError(f"Expected to mask {n_masks} tokens, but masked {n_masks_final} tokens.")

        input_sequence_masked = " ".join(masked_input_tokens)
        masked_tokens = [' '.join(tokens) for tokens in masked_tokens]

        print(input_sequence)
        print(masked_input_tokens)
        print(span_lengths)
        print(mask_tokens_indices)

    except Exception as e:
        print(f"Error during masking: {e}")
        # If an error occurs during masking, set values to None
        input_sequence = None
        input_sequence_masked = None
        masked_tokens = None
        n_masks = None
        duplicate_count = None

    # Initialize DataFrame to store masked sequences and other information
    masked_sequences_df_temp = None

    # Check if the DataFrame exists, if not, create it
    if masked_sequences_df_temp is None:
        masked_sequences_df_temp = pd.DataFrame(columns=["Input sequence (ground truth)", "Input sequence (masked)", "Masked tokens"])

    # Create a new row of data for the DataFrame
    new_data = {
        "Input sequence (ground truth)": [input_sequence],
        "Input sequence (masked)": [input_sequence_masked],
        "Masked tokens": [masked_tokens],
        "Number of masked tokens": [n_masks],
        "Masking percentage": [mask_perc*100],
        "Duplicate count": [duplicate_count]
    }

    # Add the new data to the DataFrame
    masked_sequences_df_temp = pd.DataFrame(new_data)

    return masked_sequences_df_temp

# %%
masked_sequences_df = None
data = data

for i in range(len(data)):
  print(i)
  masked_sequences_df_temp = mask_input(data.iloc[i], mask_perc=MASK_PERC, noise_span_length=3)
  # Add results to df
  masked_sequences_df = pd.concat([masked_sequences_df, masked_sequences_df_temp], ignore_index=True)
# Out:
# 0
# Met een spectaculaire reddingsoperatie wist het Isralische leger zaterdag vier gijzelaars te bevrijden. De prijs aan Palestijnse zijde is echter ongekend hoog. Wat betekent deze actie voor de ongeveer 120 gijzelaars die nog vastzitten? En waarom zwijgen de meeste wereldleiders? Vijf vragen beantwoord.
# ['Met', 'een', 'spectaculaire', 'reddingsoperatie', 'wist', 'het', 'Isralische', '<extra_id_0>', 'te', 'bevrijden.', 'De', 'prijs', 'aan', 'Palestijnse', 'zijde', 'is', 'echter', 'ongekend', 'hoog.', 'Wat', 'betekent', 'deze', 'actie', 'voor', 'de', 'ongeveer', '120', '<extra_id_1>', 'vastzitten?', 'En', 'waarom', '<extra_id_2>', 'wereldleiders?', '<extra_id_3>']
# [4, 3, 3, 3]
# [7, 8, 9, 10, 30, 31, 32, 36, 37, 38, 40, 41, 42]
# 1
# Met een spectaculaire reddingsoperatie wist het Isralische leger zaterdag vier gijzelaars te bevrijden. De prijs aan Palestijnse zijde is echter ongekend hoog. Wat betekent deze actie voor de ongeveer 120 gijzelaars die nog vastzitten? En waarom zwijgen de meeste wereldleiders? Vijf vragen beantwoord.
# ['Met', 'een', 'spectaculaire', '<extra_id_0>', 'Isralische', 'leger', 'zaterdag', 'vier', 'gijzelaars', '<extra_id_1>', 'aan', 'Palestijnse', 'zijde', 'is', 'echter', 'ongekend', 'hoog.', 'Wat', 'betekent', 'deze', 'actie', 'voor', 'de', 'ongeveer', '120', 'gijzelaars', 'die', 'nog', 'vastzitten?', 'En', 'waarom', '<extra_id_2>', 'wereldleiders?', '<extra_id_3>']
# [3, 4, 3, 3]
# [3, 4, 5, 11, 12, 13, 14, 36, 37, 38, 40, 41, 42]
# 2
# Op 1 juni begint de Nederlander Hermen Hulst als ceo van Sony Interactive Entertainment, de maker van PlayStation. Voorheen produceerde Hulst de succesvolle gameseries Killzone en Horizon. Hij krijgt de taak om s werelds grootste gamebedrijf door een tumultueuze tijd in de game-industrie te leiden.
# ['Op', '1', 'juni', 'begint', 'de', 'Nederlander', 'Hermen', 'Hulst', '<extra_id_0>', 'Sony', 'Interactive', '<extra_id_1>', 'van', 'PlayStation.', 'Voorheen', 'produceerde', 'Hulst', 'de', 'succesvolle', 'gameseries', 'Killzone', 'en', 'Horizon.', '<extra_id_2>', 'taak', 'om', 's', 'werelds', 'grootste', 'gamebedrijf', 'door', 'een', 'tumultueuze', '<extra_id_3>', 'game-industrie', '<extra_id_4>']
# [3, 3, 3, 3, 2]
# [8, 9, 10, 13, 14, 15, 27, 28, 29, 39, 40, 41, 43, 44]
# 3
# De liberaal-conservatieve Nieuw-Vlaamse Alliantie (N-VA) blijft de grootste partij in het Vlaams Parlement (25,2 procent). Dat melden Belgische media op basis van de helft van de getelde stemmen van de regionale verkiezingen, die vandaag tegelijk met de Europese en landelijke verkiezingen plaatsvonden.
# ['De', 'liberaal-conservatieve', 'Nieuw-Vlaamse', '<extra_id_0>', 'grootste', 'partij', 'in', 'het', 'Vlaams', 'Parlement', '(25,2', 'procent).', 'Dat', 'melden', '<extra_id_1>', 'basis', 'van', 'de', 'helft', 'van', 'de', 'getelde', 'stemmen', 'van', '<extra_id_2>', 'die', 'vandaag', 'tegelijk', 'met', 'de', 'Europese', '<extra_id_3>', 'plaatsvonden.']
# [4, 3, 3, 3]
# [3, 4, 5, 6, 17, 18, 19, 29, 30, 31, 38, 39, 40]
# 4
# De elfde editie van de Willem IV Rally was een groot succes. Dat meldt Arne Verwoert van de organisatie. Dit jaar is er ruim 11.500 euro opgehaald voor het Ronald McDonald Huis Sophia Rotterdam. ,,De jongste deelnemer ooit, van dertien jaar oud, is samen met haar vader eerste geworden.
# ['<extra_id_0>', 'van', 'de', 'Willem', 'IV', 'Rally', 'was', 'een', 'groot', 'succes.', 'Dat', 'meldt', 'Arne', 'Verwoert', 'van', 'de', 'organisatie.', 'Dit', 'jaar', 'is', 'er', 'ruim', '11.500', 'euro', 'opgehaald', 'voor', '<extra_id_1>', 'Huis', 'Sophia', '<extra_id_2>', 'deelnemer', 'ooit,', 'van', 'dertien', 'jaar', 'oud,', '<extra_id_3>', 'haar', '<extra_id_4>']
# [3, 3, 3, 3, 3]
# [0, 1, 2, 28, 29, 30, 33, 34, 35, 42, 43, 44, 46, 47, 48]
# 5
# Lieke Martens kon met een overwinning afscheid van het thuispubliek. Maar ze laat een kwetsbaar team achter, waarvan niemand vooralsnog kan inschatten waartoe het in staat is.
# ['Lieke', 'Martens', 'kon', 'met', 'een', '<extra_id_0>', 'het', 'thuispubliek.', 'Maar', 'ze', 'laat', 'een', 'kwetsbaar', 'team', 'achter,', 'waarvan', 'niemand', 'vooralsnog', '<extra_id_1>', 'waartoe', '<extra_id_2>', 'is.']
# [3, 2, 3]
# [5, 6, 7, 20, 21, 23, 24, 25]
# 6
# NRC bespreekt deze weken de eindexamens na met deskundigen. Internist Jos Kooter over het vmbo gl- en tl-examen natuur- en scheikunde.
# ['NRC', 'bespreekt', 'deze', 'weken', 'de', 'eindexamens', 'na', 'met', 'deskundigen.', 'Internist', 'Jos', '<extra_id_0>', 'vmbo', 'gl-', 'en', '<extra_id_1>', 'scheikunde.']
# [3, 3]
# [11, 12, 13, 17, 18, 19]
# 7
# De Conservatieve Britse premier Sunak schreef twee weken geleden onverwachts verkiezingen uit. De campagnestrijd met Labour ging meteen volop van start. Maandag kwam Nigel Farage met een verrassing: hij doet alsnog mee.
# ['De', 'Conservatieve', 'Britse', 'premier', 'Sunak', 'schreef', '<extra_id_0>', 'verkiezingen', '<extra_id_1>', 'met', '<extra_id_2>', 'volop', 'van', 'start.', 'Maandag', 'kwam', 'Nigel', 'Farage', 'met', 'een', 'verrassing:', 'hij', 'doet', 'alsnog', 'mee.']
# [4, 3, 3]
# [6, 7, 8, 9, 11, 12, 13, 15, 16, 17]
# 8
# Wie noodgedwongen zzper wordt, heeft het minder goed dan zelfstandigen die daar bewust voor kiezen, blijkt uit onderzoek van Rabobank.
# ['Wie', 'noodgedwongen', 'zzper', 'wordt,', 'heeft', 'het', 'minder', 'goed', 'dan', '<extra_id_0>', 'bewust', 'voor', 'kiezen,', 'blijkt', '<extra_id_1>', 'Rabobank.']
# [3, 3]
# [9, 10, 11, 16, 17, 18]
# 9
# Amsterdammers mogen donderdag behalve voor het Europees Parlement ook stemmen over groen in hun stad.
# ['Amsterdammers', 'mogen', 'donderdag', 'behalve', 'voor', 'het', 'Europees', '<extra_id_0>', 'groen', 'in', 'hun', 'stad.']
# [4]
# [7, 8, 9, 10]
# 10
# Drie docenten van de zeevaartschool op Terschelling verloren hun baan na onderzoek over grensoverschrijdend gedrag. Dat onderzoek bleek niet te deugen  maar de sociale verhoudingen op het eiland staan nu wel op scherp.
# ['Drie', 'docenten', 'van', 'de', 'zeevaartschool', 'op', '<extra_id_0>', 'baan', 'na', 'onderzoek', 'over', 'grensoverschrijdend', '<extra_id_1>', 'niet', '<extra_id_2>', 'de', 'sociale', 'verhoudingen', 'op', 'het', 'eiland', 'staan', 'nu', 'wel', 'op', 'scherp.']
# [3, 4, 3]
# [6, 7, 8, 14, 15, 16, 17, 19, 20, 21]
# 11
# Netbeheerder Tennet heeft met de aanleg van een stroomkabel mogelijk onomkeerbare schade aangebracht aan kwetsbare natuur op landgoed Twickel, concludeerde de provincie Overijssel donderdag. In Twente is te zien hoe klimaatdoelen botsen met de natuuropgave.
# ['Netbeheerder', 'Tennet', 'heeft', 'met', 'de', 'aanleg', '<extra_id_0>', 'mogelijk', 'onomkeerbare', 'schade', 'aangebracht', 'aan', 'kwetsbare', 'natuur', 'op', 'landgoed', 'Twickel,', 'concludeerde', '<extra_id_1>', 'In', 'Twente', 'is', '<extra_id_2>', 'klimaatdoelen', 'botsen', 'met', 'de', 'natuuropgave.']
# [3, 4, 3]
# [6, 7, 8, 20, 21, 22, 23, 27, 28, 29]
# 12
# Omdat grote banken nauwelijks met elkaar hoeven concurreren om spaarders, ontvangen klanten te lage rentes, concludeert ACM. De toezichthouder stelt onder meer het opzetten van een onafhankelijke vergelijkingssite voor.
# ['Omdat', 'grote', 'banken', 'nauwelijks', 'met', '<extra_id_0>', 'om', 'spaarders,', 'ontvangen', 'klanten', 'te', 'lage', 'rentes,', 'concludeert', '<extra_id_1>', 'stelt', 'onder', '<extra_id_2>', 'van', 'een', 'onafhankelijke', 'vergelijkingssite', 'voor.']
# [3, 3, 3]
# [5, 6, 7, 16, 17, 18, 21, 22, 23]
# 13
# Een kaalslag dreigt onder installateurs van zonnepanelen in Nederland. Niet alleen zijn de energieprijzen gezakt, ook de lucratieve salderingsregeling heeft haar langste tijd gehad.
# ['Een', 'kaalslag', 'dreigt', 'onder', 'installateurs', 'van', 'zonnepanelen', 'in', 'Nederland.', 'Niet', 'alleen', 'zijn', '<extra_id_0>', 'ook', 'de', 'lucratieve', '<extra_id_1>', 'tijd', 'gehad.']
# [3, 4]
# [12, 13, 14, 18, 19, 20, 21]
# 14
# In Wenen is een nieuw museum geopend dat gewijd is aan het Wiener Aktionismus, dat in de jaren zestig Oostenrijk opschudde met voorstellingen vol bloed en uitwerpselen. Had het beter vergeten kunnen worden?
# ['In', 'Wenen', 'is', 'een', 'nieuw', 'museum', 'geopend', 'dat', 'gewijd', 'is', 'aan', '<extra_id_0>', 'dat', 'in', '<extra_id_1>', 'opschudde', 'met', 'voorstellingen', 'vol', 'bloed', 'en', 'uitwerpselen.', 'Had', 'het', '<extra_id_2>', 'worden?']
# [3, 4, 3]
# [11, 12, 13, 16, 17, 18, 19, 29, 30, 31]
# 15
# Is dit fascisme? Het is de vraag die telkens terugkomt. Baudets opmerking over homeopathische verdunning: is dit fascisme? De bestorming van het Capitool: is dit fascisme? Poetins strijd tegen -lhbti-activisten: is dit fascisme?
# ['Is', 'dit', 'fascisme?', 'Het', 'is', 'de', 'vraag', 'die', 'telkens', 'terugkomt.', 'Baudets', 'opmerking', 'over', 'homeopathische', 'verdunning:', 'is', 'dit', '<extra_id_0>', 'het', 'Capitool:', '<extra_id_1>', 'Poetins', 'strijd', '<extra_id_2>', 'dit', 'fascisme?']
# [4, 3, 3]
# [17, 18, 19, 20, 23, 24, 25, 28, 29, 30]
# 16
# De discotheek is aan het verdwijnen in Itali. Van de ruim zevenduizend danspaleizen die eind jaren 90 in het land stonden, is nog maar de helft over. De rest is vervallen, verlaten of omgebouwd tot supermarkt of kantoor.
# ['De', 'discotheek', 'is', 'aan', 'het', 'verdwijnen', 'in', '<extra_id_0>', 'ruim', '<extra_id_1>', 'die', 'eind', 'jaren', '90', 'in', 'het', 'land', 'stonden,', 'is', 'nog', 'maar', 'de', 'helft', 'over.', 'De', 'rest', '<extra_id_2>', 'of', 'omgebouwd', 'tot', '<extra_id_3>']
# [3, 2, 3, 3]
# [7, 8, 9, 11, 12, 29, 30, 31, 35, 36, 37]
# 17
# De totale waarde van de export van Made in Holland-producten is vorig jaar met ruim 5 procent gedaald ten opzichte van 2022. Er werd voor 19 miljard euro minder aan Nederlandse producten uitgevoerd dan een jaar eerder, meldt het Centraal Bureau voor de Statistiek (CBS).
# ['De', 'totale', 'waarde', 'van', 'de', 'export', 'van', 'Made', 'in', 'Holland-producten', 'is', 'vorig', 'jaar', 'met', 'ruim', '5', 'procent', 'gedaald', 'ten', '<extra_id_0>', '2022.', 'Er', '<extra_id_1>', 'miljard', 'euro', 'minder', 'aan', '<extra_id_2>', 'dan', 'een', '<extra_id_3>', 'het', 'Centraal', 'Bureau', 'voor', '<extra_id_4>']
# [2, 3, 3, 3, 3]
# [19, 20, 23, 24, 25, 30, 31, 32, 35, 36, 37, 42, 43, 44]
# 18
# Schrijven betaalt de hypotheek niet, daarom is Walter van den Berg ook Salesforce Marketing Cloud Developer  een bullshitbaan?
# ['Schrijven', 'betaalt', 'de', 'hypotheek', 'niet,', 'daarom', 'is', 'Walter', 'van', 'den', 'Berg', '<extra_id_0>', 'Cloud', '<extra_id_1>', 'bullshitbaan?']
# [3, 2]
# [11, 12, 13, 15, 16]
# 19
# Miljoenen Afghanen leven onder de armoedegrens. Buitenlandse donoren bieden weinig hulp omdat de Taliban vrouwenrechten drastisch beperkten. Vermindering van de internationale hulp zal dezelfde Afghaanse vrouwen die we hopen te steunen alleen maar meer laten lijden.
# ['Miljoenen', 'Afghanen', 'leven', 'onder', 'de', 'armoedegrens.', 'Buitenlandse', '<extra_id_0>', 'hulp', '<extra_id_1>', 'Taliban', 'vrouwenrechten', 'drastisch', 'beperkten.', 'Vermindering', 'van', 'de', 'internationale', 'hulp', 'zal', 'dezelfde', 'Afghaanse', 'vrouwen', 'die', 'we', 'hopen', '<extra_id_2>', 'maar', '<extra_id_3>']
# [3, 2, 3, 3]
# [7, 8, 9, 11, 12, 29, 30, 31, 33, 34, 35]
# 20
# Schrijven betaalt de hypotheek niet, daarom is Walter van den Berg ook Salesforce Marketing Cloud Developer  een bullshitbaan?
# ['Schrijven', 'betaalt', 'de', 'hypotheek', 'niet,', 'daarom', 'is', 'Walter', '<extra_id_0>', 'ook', 'Salesforce', 'Marketing', '<extra_id_1>', 'een', 'bullshitbaan?']
# [3, 2]
# [8, 9, 10, 14, 15]
# 21
# Het COA, dat kampt met een structureel tekort aan opvangplekken, is zeer te spreken over de stap naar voren van Arnhem.
# ['Het', 'COA,', 'dat', 'kampt', 'met', 'een', 'structureel', '<extra_id_0>', 'is', 'zeer', 'te', 'spreken', 'over', 'de', 'stap', '<extra_id_1>', 'Arnhem.']
# [3, 3]
# [7, 8, 9, 17, 18, 19]
# 22
# Het Openbaar Ministerie gaat de radicaal-rechtse complotdenker Raisa Blommestijn vervolgen voor groepsbelediging en smaad. Aanleiding zijn berichten op X waarin ze zwarte mannen uitmaakt voor negrode primaten en iemand onterecht beschuldigt van pedoseskualiteit.
# ['Het', 'Openbaar', 'Ministerie', 'gaat', 'de', 'radicaal-rechtse', '<extra_id_0>', 'voor', 'groepsbelediging', 'en', 'smaad.', 'Aanleiding', 'zijn', 'berichten', 'op', 'X', 'waarin', 'ze', 'zwarte', 'mannen', 'uitmaakt', 'voor', '<extra_id_1>', 'iemand', '<extra_id_2>', 'pedoseskualiteit.']
# [4, 3, 3]
# [6, 7, 8, 9, 25, 26, 27, 29, 30, 31]
# 23
# Het Openbaar Ministerie heeft een nieuwe kroongetuige gepresenteerd. Het gaat om de 29-jarige Dominique K. Hij heeft openheid van zaken gegeven over moorden en geweldszaken in Amsterdam en Rotterdam uit 2020 en 2021. De gewelddadigheden houden verband met een vete in de onderwereld, waarbij een bedrag van 130 miljoen euro zou zijn gestolen. De kroongetuigedeal is gesloten door het OM in Amsterdam.
# ['Het', 'Openbaar', 'Ministerie', 'heeft', 'een', 'nieuwe', 'kroongetuige', 'gepresenteerd.', 'Het', 'gaat', 'om', 'de', '29-jarige', 'Dominique', 'K.', 'Hij', 'heeft', 'openheid', 'van', 'zaken', 'gegeven', 'over', 'moorden', 'en', '<extra_id_0>', 'en', 'Rotterdam', '<extra_id_1>', '2021.', 'De', 'gewelddadigheden', '<extra_id_2>', 'vete', 'in', 'de', 'onderwereld,', 'waarbij', 'een', '<extra_id_3>', 'miljoen', 'euro', 'zou', 'zijn', 'gestolen.', '<extra_id_4>', 'gesloten', 'door', '<extra_id_5>', 'Amsterdam.']
# [3, 3, 4, 3, 3, 3]
# [24, 25, 26, 29, 30, 31, 35, 36, 37, 38, 45, 46, 47, 53, 54, 55, 58, 59, 60]
# 24
# Wonen in een comfortabel verwarmd huis van steen met een pannendak: dat was voor het gros van de mensen in het verleden een utopie.
# ['Wonen', 'in', 'een', 'comfortabel', 'verwarmd', 'huis', 'van', 'steen', 'met', 'een', 'pannendak:', 'dat', 'was', 'voor', 'het', 'gros', '<extra_id_0>', 'in', '<extra_id_1>']
# [3, 4]
# [16, 17, 18, 20, 21, 22, 23]
# 25
# Onder de Nederlandse bevolking is weinig steun voor Israls oorlog in Gaza. Slechts eenvijfde van de bevolking vindt dat de Isralische bombardementen in Gaza nodig zijn om Hamas uit te schakelen. Eenzelfde deel van de bevolking is voor militaire samenwerking met Isral.
# ['Onder', 'de', 'Nederlandse', 'bevolking', 'is', 'weinig', '<extra_id_0>', 'oorlog', 'in', 'Gaza.', 'Slechts', 'eenvijfde', 'van', 'de', 'bevolking', 'vindt', 'dat', 'de', 'Isralische', 'bombardementen', 'in', 'Gaza', '<extra_id_1>', 'Hamas', '<extra_id_2>', 'deel', 'van', 'de', 'bevolking', 'is', 'voor', '<extra_id_3>', 'Isral.']
# [3, 3, 4, 3]
# [6, 7, 8, 24, 25, 26, 28, 29, 30, 31, 38, 39, 40]
# 26
# De Amsterdamse burgemeester Halsema wilde in gesprek met pro-Palestijnse demonstranten, die dat aangrepen als een nieuwe kans om te demonsteren. Halsema prees hun engagement: Het ontroert me dat de studenten zo betrokken zijn bij internationale politiek.
# ['De', '<extra_id_0>', 'wilde', 'in', 'gesprek', 'met', 'pro-Palestijnse', '<extra_id_1>', 'aangrepen', 'als', 'een', 'nieuwe', 'kans', 'om', 'te', 'demonsteren.', 'Halsema', 'prees', '<extra_id_2>', 'ontroert', 'me', 'dat', 'de', 'studenten', '<extra_id_3>', 'zijn', 'bij', 'internationale', 'politiek.']
# [3, 3, 3, 2]
# [1, 2, 3, 9, 10, 11, 22, 23, 24, 30, 31]
# 27
# De luchthaven mag volgend jaar toch meer vluchten uitvoeren dan de regering twee jaar geleden aankondigde. De geluidshinder van de luchthaven wil het kabinet nu bestrijden met extra operationele maatregelen.
# ['De', 'luchthaven', 'mag', 'volgend', '<extra_id_0>', 'vluchten', 'uitvoeren', 'dan', 'de', 'regering', 'twee', 'jaar', 'geleden', '<extra_id_1>', 'van', 'de', 'luchthaven', 'wil', 'het', 'kabinet', 'nu', 'bestrijden', 'met', '<extra_id_2>']
# [3, 3, 3]
# [4, 5, 6, 15, 16, 17, 27, 28, 29]
# 28
# De Chinese president Xi Jinping doet een nieuwe poging om minder afhankelijk te worden van de Verenigde Staten en zijn bondgenoten. De VS willen op hun beurt juist voorkomen dat China zelfstandiger wordt als het om chips gaat.
# ['De', 'Chinese', 'president', 'Xi', 'Jinping', 'doet', 'een', 'nieuwe', 'poging', '<extra_id_0>', 'te', '<extra_id_1>', 'Verenigde', 'Staten', 'en', 'zijn', 'bondgenoten.', 'De', 'VS', 'willen', 'op', 'hun', 'beurt', 'juist', 'voorkomen', 'dat', 'China', '<extra_id_2>', 'als', '<extra_id_3>', 'gaat.']
# [3, 3, 2, 3]
# [9, 10, 11, 13, 14, 15, 31, 32, 34, 35, 36]
# 29
# Op amper 3 minuten van de grens bij Enschede, in Gronau, runt Gerhard Becker (58) zijn nieuwe winkel Tabak XXL. Een paradijs voor rokers die hoge accijnzen willen ontwijken.
# ['Op', 'amper', '<extra_id_0>', 'de', 'grens', 'bij', 'Enschede,', 'in', 'Gronau,', 'runt', 'Gerhard', 'Becker', '(58)', 'zijn', 'nieuwe', 'winkel', 'Tabak', 'XXL.', 'Een', '<extra_id_1>', 'die', 'hoge', '<extra_id_2>']
# [3, 3, 3]
# [2, 3, 4, 21, 22, 23, 26, 27, 28]
# 30
# Dubbele seksuele moraal is achterhaald, laat vrouwen ook kinderen hebben bij verschillende mensen
# ['Dubbele', 'seksuele', 'moraal', 'is', '<extra_id_0>', 'kinderen', 'hebben', 'bij', 'verschillende', 'mensen']
# [4]
# [4, 5, 6, 7]
# 31
# De komende coalitie wil landbouwers steunen door brandstof goedkoper te maken. Tot 2013 betaalden ze ook al minder accijns.
# ['De', 'komende', 'coalitie', 'wil', 'landbouwers', 'steunen', 'door', 'brandstof', 'goedkoper', 'te', '<extra_id_0>', 'betaalden', 'ze', '<extra_id_1>', 'accijns.']
# [3, 3]
# [10, 11, 12, 15, 16, 17]
# 32
# Het hoofdlijnenakkoord van het kabinet-in-wording begint met een gedicht. Nederland is een prachtig land./ Een land om trots op te zijn. En zo gaat het nog een beetje door, totdat er onverwacht een lange zin volgt. Politiek en bestuur hebben ondanks goede bedoelingen de afgelopen jaren steken laten vallen, door de zorgen van mensen niet altijd serieus te nemen.
# ['Het', 'hoofdlijnenakkoord', 'van', 'het', 'kabinet-in-wording', 'begint', '<extra_id_0>', 'Nederland', 'is', 'een', 'prachtig', 'land./', 'Een', 'land', 'om', 'trots', 'op', 'te', 'zijn.', 'En', 'zo', 'gaat', '<extra_id_1>', 'beetje', 'door,', '<extra_id_2>', 'een', 'lange', 'zin', 'volgt.', 'Politiek', 'en', 'bestuur', 'hebben', 'ondanks', '<extra_id_3>', 'afgelopen', 'jaren', 'steken', 'laten', 'vallen,', '<extra_id_4>', 'van', 'mensen', 'niet', '<extra_id_5>', 'nemen.']
# [3, 3, 3, 3, 3, 3]
# [6, 7, 8, 24, 25, 26, 29, 30, 31, 41, 42, 43, 49, 50, 51, 55, 56, 57]
# 33
# Nabestaanden van de slachtoffers van een massaschietpartij in een basisschool in de Amerikaanse staat Connecticut, in 2012, hebben vrijdag een vergoedingsvoorstel aanvaard van de failliete complotdenker Alex Jones.
# ['Nabestaanden', 'van', 'de', '<extra_id_0>', 'massaschietpartij', 'in', 'een', 'basisschool', 'in', 'de', 'Amerikaanse', 'staat', 'Connecticut,', 'in', '<extra_id_1>', 'vrijdag', 'een', 'vergoedingsvoorstel', '<extra_id_2>', 'failliete', 'complotdenker', 'Alex', 'Jones.']
# [3, 2, 3]
# [3, 4, 5, 16, 17, 21, 22, 23]
# 34
# De prijs voor Hollandse garnalen is zo hoog opgelopen dat restaurants garnalencocktails en kroketten van de menukaart halen. Het is exemplarisch voor de situatie van de Nederlandse visserij. De sector maakte in 2023 een verlies van 3,1 miljoen euro, aldus onderzoekers van Universiteit Wageningen.
# ['De', 'prijs', 'voor', 'Hollandse', 'garnalen', 'is', 'zo', 'hoog', '<extra_id_0>', 'garnalencocktails', 'en', 'kroketten', 'van', 'de', 'menukaart', 'halen.', 'Het', '<extra_id_1>', 'situatie', 'van', 'de', 'Nederlandse', 'visserij.', 'De', 'sector', '<extra_id_2>', 'een', 'verlies', '<extra_id_3>', 'euro,', 'aldus', 'onderzoekers', 'van', 'Universiteit', 'Wageningen.']
# [3, 4, 3, 3]
# [8, 9, 10, 19, 20, 21, 22, 30, 31, 32, 35, 36, 37]
# 35
# Uitvoeringsinstanties zoals de Belastingdienst en het UWV moeten een rode kaart kunnen trekken als ze worden gedwongen beleid uit te voeren dat burgers in de knel brengt.
# ['Uitvoeringsinstanties', 'zoals', 'de', 'Belastingdienst', 'en', 'het', 'UWV', 'moeten', 'een', '<extra_id_0>', 'trekken', 'als', 'ze', 'worden', '<extra_id_1>', 'te', 'voeren', '<extra_id_2>', 'in', 'de', 'knel', 'brengt.']
# [3, 3, 2]
# [9, 10, 11, 16, 17, 18, 21, 22]
# 36
# Het Nederlands elftal begint maandag aan een reis die idealiter zondag 14 juli eindigt met de EK finale in Berlijn.
# ['Het', 'Nederlands', 'elftal', 'begint', 'maandag', 'aan', '<extra_id_0>', 'idealiter', 'zondag', '14', 'juli', 'eindigt', 'met', 'de', 'EK', '<extra_id_1>']
# [3, 3]
# [6, 7, 8, 17, 18, 19]
# 37
# Garry Conille, nog geen twee weken geleden als tijdelijke premier van Hati aangesteld, is zaterdag in het ziekenhuis in Port-au-Prince opgenomen.
# ['Garry', 'Conille,', 'nog', 'geen', 'twee', 'weken', 'geleden', '<extra_id_0>', 'van', 'Hati', 'aangesteld,', 'is', 'zaterdag', 'in', 'het', 'ziekenhuis', '<extra_id_1>']
# [3, 3]
# [7, 8, 9, 18, 19, 20]
# 38
# Op amper 3 minuten van de grens bij Enschede, in Gronau, runt Gerhard Becker (58) zijn nieuwe winkel Tabak XXL. Een paradijs voor rokers die hoge accijnzen willen ontwijken. Twentse supermarkten balen, Duitse ondernemers profiteren. Ze halen winkelkarren vol shag.
# ['Op', 'amper', '3', 'minuten', 'van', 'de', '<extra_id_0>', 'in', 'Gronau,', 'runt', 'Gerhard', 'Becker', '(58)', '<extra_id_1>', 'Tabak', 'XXL.', 'Een', 'paradijs', 'voor', 'rokers', 'die', 'hoge', 'accijnzen', 'willen', 'ontwijken.', 'Twentse', '<extra_id_2>', 'ondernemers', '<extra_id_3>', 'winkelkarren', 'vol', 'shag.']
# [3, 3, 3, 3]
# [6, 7, 8, 15, 16, 17, 30, 31, 32, 34, 35, 36]
# 39
# Primoz Roglic heeft Critrium du Dauphin op zijn naam geschreven. De Sloveen van BORA-hansgrohe sloot de Franse rittenkoers af met een voorsprong van acht seconden ten opzichte van Matteo Jorgensen van Visma-Lease a Bike. Carlos Rodriguez won de laatste etappe.
# ['Primoz', '<extra_id_0>', 'du', '<extra_id_1>', 'naam', 'geschreven.', 'De', 'Sloveen', 'van', 'BORA-hansgrohe', 'sloot', 'de', '<extra_id_2>', 'met', 'een', 'voorsprong', 'van', 'acht', 'seconden', 'ten', 'opzichte', 'van', 'Matteo', 'Jorgensen', 'van', 'Visma-Lease', 'a', 'Bike.', 'Carlos', '<extra_id_3>', 'laatste', 'etappe.']
# [3, 3, 3, 3]
# [1, 2, 3, 5, 6, 7, 16, 17, 18, 35, 36, 37]
# 40
# De eindexamens in het voortgezet onderwijs zijn op stoom. De komende weken doet de Volkskrant verslag. Debbie de Jong, deelnemer aan het reality programma B&B Vol Liefde, buigt zich over het examen Spaans voor vmbo gl/tl, de gemengde en theoretische leerweg.
# ['<extra_id_0>', 'het', 'voortgezet', 'onderwijs', 'zijn', 'op', '<extra_id_1>', 'weken', 'doet', 'de', 'Volkskrant', 'verslag.', 'Debbie', 'de', 'Jong,', 'deelnemer', 'aan', 'het', 'reality', 'programma', 'B&B', 'Vol', 'Liefde,', 'buigt', 'zich', 'over', 'het', 'examen', '<extra_id_2>', 'gl/tl,', 'de', '<extra_id_3>', 'leerweg.']
# [3, 3, 3, 3]
# [0, 1, 2, 8, 9, 10, 32, 33, 34, 37, 38, 39]
# 41
# Iedereen was enthousiast over de methode-Laurentien voor de compensatie van toeslagenouders, totdat de uitgekeerde bedragen bekend werden  gemiddeld ruim 120 duizend euro per gedupeerde.
# ['Iedereen', '<extra_id_0>', 'methode-Laurentien', 'voor', '<extra_id_1>', 'toeslagenouders,', 'totdat', 'de', 'uitgekeerde', 'bedragen', 'bekend', 'werden', 'gemiddeld', 'ruim', '120', 'duizend', 'euro', 'per', 'gedupeerde.']
# [4, 3]
# [1, 2, 3, 4, 7, 8, 9]
# 42
# De gemeente Zundert schitterde dinsdag bij de Raad van State door afwezigheid, terwijl rechter Jan van Breda heel wat vragen wilde stellen over het campingbeleid van de gemeente.
# ['De', 'gemeente', 'Zundert', 'schitterde', 'dinsdag', '<extra_id_0>', 'Raad', 'van', '<extra_id_1>', 'terwijl', 'rechter', 'Jan', 'van', 'Breda', 'heel', 'wat', 'vragen', 'wilde', 'stellen', 'over', 'het', '<extra_id_2>', 'gemeente.']
# [2, 3, 3]
# [5, 6, 9, 10, 11, 24, 25, 26]
# 43
# Nigerianen tonen opvallend veel begrip voor de staking die het hele land in het donker heeft gezet.
# ['Nigerianen', 'tonen', '<extra_id_0>', 'begrip', 'voor', 'de', 'staking', 'die', '<extra_id_1>', 'in', 'het', 'donker', 'heeft', 'gezet.']
# [2, 3]
# [2, 3, 9, 10, 11]
# 44
# Deze donderdagmiddag neemt de Europese Centrale Bank 99 procent zeker een besluit waar de financile markten al maanden smachtend naar uitkijken: een renteverlaging. Maar loopt de ECB daarmee niet het gevaar dat de inflatie weer de lucht in schiet?
# ['<extra_id_0>', 'de', 'Europese', 'Centrale', 'Bank', '99', 'procent', 'zeker', 'een', 'besluit', 'waar', 'de', 'financile', 'markten', 'al', 'maanden', '<extra_id_1>', 'een', 'renteverlaging.', 'Maar', 'loopt', 'de', 'ECB', 'daarmee', 'niet', 'het', 'gevaar', '<extra_id_2>', 'weer', '<extra_id_3>', 'schiet?']
# [3, 3, 3, 3]
# [0, 1, 2, 18, 19, 20, 31, 32, 33, 35, 36, 37]
# 45
# Bente van de Wouw (29) leefde jaren als extravert, terwijl ze toch echt heel introvert is.
# ['Bente', 'van', 'de', 'Wouw', '(29)', 'leefde', 'jaren', '<extra_id_0>', 'terwijl', 'ze', '<extra_id_1>', 'introvert', 'is.']
# [2, 3]
# [7, 8, 11, 12, 13]
# 46
# Na eerdere problemen rond de vergunning mag de bouw van een boorplatform in de Noordzee worden hervat.
# ['Na', 'eerdere', 'problemen', 'rond', 'de', 'vergunning', 'mag', 'de', 'bouw', 'van', '<extra_id_0>', 'de', 'Noordzee', '<extra_id_1>']
# [3, 2]
# [10, 11, 12, 15, 16]
# 47
# Nederlanders douchen steeds meer, liefst twee keer per dag, met warm water en veel sop. Volgens dermatologen is dat echt te veel voor onze huid.
# ['<extra_id_0>', 'meer,', 'liefst', 'twee', 'keer', 'per', 'dag,', '<extra_id_1>', 'water', '<extra_id_2>', 'Volgens', 'dermatologen', 'is', 'dat', 'echt', 'te', 'veel', 'voor', 'onze', 'huid.']
# [3, 2, 3]
# [0, 1, 2, 9, 10, 12, 13, 14]
# 48
# Griekenland stuurt asielzoekers die al aan land zijn terug de zee op en laat hen achter in rubberbootjes, hebben ngos en journalisten gedocumenteerd.
# ['<extra_id_0>', 'al', 'aan', 'land', 'zijn', 'terug', 'de', 'zee', 'op', 'en', 'laat', 'hen', 'achter', 'in', 'rubberbootjes,', 'hebben', '<extra_id_1>', 'gedocumenteerd.']
# [4, 3]
# [0, 1, 2, 3, 19, 20, 21]
# 49
# De Haagse buurttuin van Janneke Vreugdenhil is een democratie: iedereen heeft een zegje, iedereen een taak. En vervolgens loopt alles altijd anders.
# ['De', 'Haagse', 'buurttuin', 'van', 'Janneke', 'Vreugdenhil', 'is', 'een', 'democratie:', 'iedereen', 'heeft', '<extra_id_0>', 'taak.', '<extra_id_1>', 'alles', 'altijd', 'anders.']
# [4, 3]
# [11, 12, 13, 14, 16, 17, 18]
# 50
# Juichen, incasseren of beleefd applaudiseren: de aanhang van de verschillende partijen reageert op de exitpoll. Met n zetel meer was het feest compleet geweest.
# ['Juichen,', 'incasseren', 'of', '<extra_id_0>', 'aanhang', 'van', 'de', 'verschillende', 'partijen', 'reageert', 'op', 'de', 'exitpoll.', '<extra_id_1>', 'was', 'het', 'feest', 'compleet', 'geweest.']
# [3, 4]
# [3, 4, 5, 15, 16, 17, 18]
# 51
# Vijf jaar geleden trad de Europese Commissie onder leiding van Ursula von der Leyen aan. Het werd een periode van grote crises en onverwachte gebeurtenissen die een ferme reactie vereisten.
# ['Vijf', 'jaar', 'geleden', 'trad', 'de', 'Europese', 'Commissie', 'onder', 'leiding', 'van', 'Ursula', 'von', 'der', 'Leyen', 'aan.', 'Het', '<extra_id_0>', 'van', '<extra_id_1>', 'onverwachte', 'gebeurtenissen', 'die', '<extra_id_2>', 'vereisten.']
# [3, 3, 3]
# [16, 17, 18, 20, 21, 22, 26, 27, 28]
# 52
# De aankondiging van een kabinet met de PVV verdeelt de toch al gesegregeerde Vrijheidswijk in Leeuwarden nog verder.
# ['De', 'aankondiging', 'van', 'een', 'kabinet', 'met', 'de', 'PVV', 'verdeelt', 'de', '<extra_id_0>', 'Vrijheidswijk', 'in', 'Leeuwarden', '<extra_id_1>']
# [3, 2]
# [10, 11, 12, 16, 17]
# 53
# Stoelen, banken, pallets, fietsen  de barricades die zijn opgeworpen door de demonstranten die het universiteitsgebouw in de Amsterdamse binnenstad hebben bezet, blijken weinig partij voor de ME.
# ['Stoelen,', 'banken,', 'pallets,', 'fietsen', 'de', 'barricades', 'die', 'zijn', '<extra_id_0>', 'demonstranten', 'die', 'het', 'universiteitsgebouw', 'in', 'de', 'Amsterdamse', '<extra_id_1>', 'bezet,', '<extra_id_2>', 'voor', 'de', 'ME.']
# [3, 2, 3]
# [8, 9, 10, 18, 19, 21, 22, 23]
# 54
# Opgegeten slablaadjes, hostas met grote gaten erin en jonggestorven stekjes. Voor de naaktslak is het een buitengewoon goed jaar. Op slakkenjacht met zussen Claudette en Mavis in hun Duivendrechtse volkstuin. Vorige week zaten we op vijfduizend slakken, nu op meer dan zesduizend.
# ['Opgegeten', 'slablaadjes,', 'hostas', 'met', 'grote', 'gaten', 'erin', 'en', 'jonggestorven', 'stekjes.', 'Voor', 'de', '<extra_id_0>', 'een', 'buitengewoon', 'goed', 'jaar.', 'Op', 'slakkenjacht', 'met', 'zussen', 'Claudette', 'en', 'Mavis', 'in', 'hun', 'Duivendrechtse', '<extra_id_1>', 'zaten', 'we', '<extra_id_2>', 'nu', '<extra_id_3>']
# [3, 3, 3, 4]
# [12, 13, 14, 29, 30, 31, 34, 35, 36, 38, 39, 40, 41]
# 55
# Tallon Griekspoor neemt het dinsdag in de eerste ronde van Roland Garros op tegen de Amerikaan MacKenzie McDonald.
# ['Tallon', 'Griekspoor', 'neemt', 'het', 'dinsdag', 'in', 'de', '<extra_id_0>', 'Roland', 'Garros', '<extra_id_1>', 'de', 'Amerikaan', 'MacKenzie', 'McDonald.']
# [3, 2]
# [7, 8, 9, 12, 13]
# 56
# De luchthaven mag volgend jaar toch meer vluchten uitvoeren dan de regering twee jaar geleden aankondigde. De geluidshinder van de luchthaven wil het kabinet nu bestrijden met extra operationele maatregelen.
# ['De', 'luchthaven', 'mag', 'volgend', 'jaar', 'toch', 'meer', 'vluchten', 'uitvoeren', 'dan', 'de', '<extra_id_0>', 'geleden', 'aankondigde.', 'De', 'geluidshinder', '<extra_id_1>', 'wil', 'het', 'kabinet', '<extra_id_2>', 'extra', 'operationele', 'maatregelen.']
# [3, 3, 3]
# [11, 12, 13, 18, 19, 20, 24, 25, 26]
# 57
# De methode van prinses Laurentien om de aanvullende schade van toeslagenouders te compenseren, mag van het ministerie alleen doorgaan als haar stichting bereid is de door het kabinet gewenste aanpassingen door te voeren.
# ['De', 'methode', 'van', 'prinses', 'Laurentien', 'om', 'de', 'aanvullende', 'schade', 'van', 'toeslagenouders', 'te', 'compenseren,', 'mag', 'van', '<extra_id_0>', 'als', 'haar', 'stichting', 'bereid', '<extra_id_1>', 'het', 'kabinet', '<extra_id_2>', 'te', 'voeren.']
# [4, 3, 3]
# [15, 16, 17, 18, 23, 24, 25, 28, 29, 30]
# 58
# De prijzen van woningen in Nederland zullen tot en met 2026 jaarlijks met 4 procent stijgen. Dat meldt De Nederlandsche Bank (DNB) bij de presentatie van de Voorjaarsramingen, de halfjaarlijkse voorspellingen voor de Nederlandse economie.
# ['De', 'prijzen', 'van', 'woningen', 'in', 'Nederland', 'zullen', '<extra_id_0>', 'jaarlijks', 'met', '4', 'procent', 'stijgen.', 'Dat', 'meldt', 'De', 'Nederlandsche', 'Bank', '(DNB)', 'bij', '<extra_id_1>', 'de', '<extra_id_2>', 'voorspellingen', 'voor', 'de', 'Nederlandse', 'economie.']
# [4, 3, 3]
# [7, 8, 9, 10, 23, 24, 25, 27, 28, 29]
# 59
# Honderden paginas aan ambtelijk commentaar op het Hoofdlijnenakkoord van PVV, VVD, NSC en BBB zijn vrijgegeven. Er zijn grote vraagtekens op allerlei terreinen, van het buitenlandbeleid en defensie tot landbouw en sociale zekerheid.
# ['Honderden', 'paginas', 'aan', 'ambtelijk', 'commentaar', 'op', 'het', 'Hoofdlijnenakkoord', 'van', 'PVV,', 'VVD,', 'NSC', 'en', 'BBB', 'zijn', '<extra_id_0>', 'vraagtekens', 'op', 'allerlei', 'terreinen,', 'van', '<extra_id_1>', 'defensie', 'tot', 'landbouw', '<extra_id_2>']
# [4, 3, 3]
# [15, 16, 17, 18, 24, 25, 26, 30, 31, 32]
# 60
# De herdenking van de landing van de geallieerden in Normandi roept vragen op over waar het Westen anno 2024 staat. De meest prangende is of westerse landen, twee jaar na de invasie in Oekrane, de wil en moed hebben om agressors te bestrijden.
# ['De', 'herdenking', 'van', 'de', 'landing', 'van', 'de', 'geallieerden', 'in', '<extra_id_0>', 'over', 'waar', 'het', 'Westen', 'anno', '2024', 'staat.', 'De', 'meest', 'prangende', 'is', 'of', 'westerse', 'landen,', 'twee', 'jaar', 'na', '<extra_id_1>', 'Oekrane,', 'de', '<extra_id_2>', 'hebben', '<extra_id_3>', 'bestrijden.']
# [4, 3, 3, 3]
# [9, 10, 11, 12, 30, 31, 32, 35, 36, 37, 39, 40, 41]
# 61
# Tijdens de eerste twee dagen van festival Best Kept Secret was het de New Yorkse St.
# ['Tijdens', 'de', 'eerste', 'twee', 'dagen', 'van', '<extra_id_0>', 'Kept', '<extra_id_1>', 'de', 'New', 'Yorkse', 'St.']
# [2, 3]
# [6, 7, 9, 10, 11]
# 62
# Vijf jaar na de stikstofuitspraak van de Raad van State is een oplossing van het probleem nog lang niet in zicht.
# ['Vijf', 'jaar', 'na', 'de', '<extra_id_0>', 'Raad', '<extra_id_1>', 'een', 'oplossing', 'van', 'het', 'probleem', 'nog', 'lang', 'niet', 'in', 'zicht.']
# [3, 3]
# [4, 5, 6, 8, 9, 10]
# 63
# Miljoenen Afghanen leven onder de armoedegrens. Buitenlandse donoren bieden weinig hulp omdat de Taliban vrouwenrechten drastisch beperkten. Vermindering van de internationale hulp zal dezelfde Afghaanse vrouwen die we hopen te steunen alleen maar meer laten lijden.
# ['Miljoenen', 'Afghanen', 'leven', 'onder', 'de', 'armoedegrens.', 'Buitenlandse', 'donoren', 'bieden', 'weinig', '<extra_id_0>', 'Taliban', 'vrouwenrechten', 'drastisch', 'beperkten.', 'Vermindering', 'van', 'de', '<extra_id_1>', 'dezelfde', 'Afghaanse', 'vrouwen', 'die', 'we', 'hopen', 'te', '<extra_id_2>', 'meer', '<extra_id_3>']
# [3, 3, 3, 2]
# [10, 11, 12, 20, 21, 22, 30, 31, 32, 34, 35]
# 64
# Een jong meisje werd door drie jongens meegenomen naar een huis en daar de hele nacht misbruikt. Maar het beeld van deze zaak, die eerst helder leek, begon te kantelen toen de politie de telefoons doorzocht.
# ['Een', 'jong', 'meisje', 'werd', 'door', 'drie', 'jongens', 'meegenomen', 'naar', 'een', 'huis', 'en', '<extra_id_0>', 'nacht', 'misbruikt.', 'Maar', 'het', 'beeld', '<extra_id_1>', 'die', '<extra_id_2>', 'begon', 'te', 'kantelen', 'toen', 'de', '<extra_id_3>', 'telefoons', 'doorzocht.']
# [3, 3, 3, 2]
# [12, 13, 14, 20, 21, 22, 24, 25, 26, 32, 33]
# 65
# Het rioolwater van huishoudens en bedrijven is een complexe cocktail van medicijnresten, cosmetische producten en chemische stoffen. Zuiveringsinstallaties krijgen het moeilijk weer schoon. Daarom moet het systeem op de schop, vindt de Europese Unie.
# ['Het', 'rioolwater', 'van', 'huishoudens', '<extra_id_0>', 'complexe', 'cocktail', 'van', 'medicijnresten,', 'cosmetische', 'producten', 'en', 'chemische', 'stoffen.', 'Zuiveringsinstallaties', 'krijgen', 'het', 'moeilijk', 'weer', 'schoon.', 'Daarom', 'moet', '<extra_id_1>', 'de', '<extra_id_2>', 'Europese', 'Unie.']
# [4, 3, 3]
# [4, 5, 6, 7, 25, 26, 27, 29, 30, 31]
# 66
# Een wetsvoorstel moet gegevensuitwisselingen tussen de overheidsdiensten en onder meer banken legaliseren. Tegenstanders van het voorstel vrezen een herhaling van de Toeslagenaffaire. Dinsdag buigt de Eerste Kamer zich erover.
# ['Een', 'wetsvoorstel', 'moet', 'gegevensuitwisselingen', 'tussen', 'de', '<extra_id_0>', 'meer', 'banken', 'legaliseren.', 'Tegenstanders', 'van', 'het', 'voorstel', 'vrezen', 'een', 'herhaling', 'van', '<extra_id_1>', 'buigt', 'de', '<extra_id_2>', 'erover.']
# [3, 3, 3]
# [6, 7, 8, 20, 21, 22, 25, 26, 27]
# 67
# Voor het eerst in de geschiedenis is er tijdens het aardbeienfeest geen koningin, maar een koning. Hein Gommers (22) is de trotse koning tijdens de veertigste editie van het aardbeienfeest in Zundert. ,,Ik heb het altijd heel leuk gevonden.
# ['Voor', 'het', 'eerst', 'in', 'de', 'geschiedenis', 'is', 'er', 'tijdens', 'het', 'aardbeienfeest', 'geen', 'koningin,', 'maar', 'een', 'koning.', '<extra_id_0>', 'is', 'de', 'trotse', 'koning', 'tijdens', '<extra_id_1>', 'van', 'het', 'aardbeienfeest', '<extra_id_2>', 'heb', 'het', 'altijd', '<extra_id_3>']
# [3, 3, 3, 3]
# [16, 17, 18, 24, 25, 26, 30, 31, 32, 36, 37, 38]
# 68
# Ook op studie- en schoolboeken gaat de btw omhoog. Scholen en universiteiten reageren teleurgesteld
# ['Ook', 'op', 'studie-', 'en', 'schoolboeken', 'gaat', 'de', 'btw', '<extra_id_0>', 'reageren', 'teleurgesteld']
# [4]
# [8, 9, 10, 11]
# 69
# Als het aan Componist des Vaderlands Anne-Maartje Lemereis ligt, wordt muziekonderwijs toegankelijk voor elk kind in Nederland: Onderwijs in muziek kan een kind creatiever, slimmer en gelukkiger maken.
# ['Als', 'het', '<extra_id_0>', 'des', '<extra_id_1>', 'ligt,', 'wordt', 'muziekonderwijs', 'toegankelijk', 'voor', 'elk', 'kind', 'in', 'Nederland:', 'Onderwijs', 'in', 'muziek', 'kan', '<extra_id_2>', 'slimmer', 'en', 'gelukkiger', 'maken.']
# [2, 3, 3]
# [2, 3, 5, 6, 7, 21, 22, 23]
# 70
# Lieke Martens kon met een overwinning afscheid van het thuispubliek. Maar ze laat een kwetsbaar team achter, waarvan niemand vooralsnog kan inschatten waartoe het in staat is.
# ['Lieke', 'Martens', 'kon', 'met', 'een', 'overwinning', 'afscheid', 'van', 'het', '<extra_id_0>', 'laat', 'een', '<extra_id_1>', 'achter,', 'waarvan', '<extra_id_2>', 'inschatten', 'waartoe', 'het', 'in', 'staat', 'is.']
# [3, 2, 3]
# [9, 10, 11, 14, 15, 18, 19, 20]
# 71
# Planbureau voor de Leefomgeving Het PBL roept provincies en Rijk op meer samen te werken om het nieuwe nationaal omgevingsbeleid van de grond te krijgen. En daarnaast schiet de uitvoeringscapaciteit enorm tekort.
# ['Planbureau', 'voor', 'de', 'Leefomgeving', 'Het', 'PBL', 'roept', 'provincies', 'en', 'Rijk', 'op', '<extra_id_0>', 'om', 'het', 'nieuwe', 'nationaal', 'omgevingsbeleid', 'van', 'de', 'grond', 'te', 'krijgen.', '<extra_id_1>', 'de', '<extra_id_2>']
# [4, 3, 3]
# [11, 12, 13, 14, 25, 26, 27, 29, 30, 31]
# 72
# Door middel van misleiding kunnen legers zich groter maken dan ze zijn. Het concept was bij het Westen wat uit de gratie geraakt, maar is door de oorlog in Oekrane weer terug.
# ['Door', 'middel', 'van', '<extra_id_0>', 'zich', 'groter', 'maken', 'dan', 'ze', 'zijn.', 'Het', 'concept', 'was', 'bij', '<extra_id_1>', 'de', 'gratie', 'geraakt,', 'maar', '<extra_id_2>', 'oorlog', 'in', 'Oekrane', 'weer', 'terug.']
# [3, 4, 3]
# [3, 4, 5, 16, 17, 18, 19, 24, 25, 26]
# 73
# India zucht onder de extreme hitte. Maar klimaatverandering was nauwelijks een thema bij de verkiezingen, waarvan dinsdag de uitslag wordt verwacht.
# ['India', 'zucht', 'onder', 'de', 'extreme', '<extra_id_0>', 'was', '<extra_id_1>', 'bij', 'de', 'verkiezingen,', 'waarvan', 'dinsdag', 'de', 'uitslag', 'wordt', 'verwacht.']
# [3, 3]
# [5, 6, 7, 9, 10, 11]
# 74
# Musicalactrice Bettina Holwerda moest leren dat afzeggen niet zwak is en overstemt het geadem van haar man met het gezoem van een ventilator.
# ['Musicalactrice', 'Bettina', '<extra_id_0>', 'afzeggen', 'niet', 'zwak', '<extra_id_1>', 'het', 'geadem', 'van', 'haar', 'man', 'met', 'het', 'gezoem', 'van', 'een', 'ventilator.']
# [4, 3]
# [2, 3, 4, 5, 9, 10, 11]
# 75
# De kandidaat van regeringspartij Morena kan, op basis van de eerste resultaten, rekenen op zon 60 procent van de stemmen. Sheinbaum lijkt daarmee de eerste vrouwelijke president van Mexico te worden.
# ['De', 'kandidaat', 'van', '<extra_id_0>', 'op', '<extra_id_1>', 'eerste', 'resultaten,', 'rekenen', 'op', 'zon', '60', 'procent', 'van', 'de', 'stemmen.', 'Sheinbaum', 'lijkt', 'daarmee', 'de', 'eerste', 'vrouwelijke', 'president', 'van', '<extra_id_2>']
# [3, 3, 3]
# [3, 4, 5, 7, 8, 9, 28, 29, 30]
# 76
# NS-personeel krijgt steeds vaker met scheldpartijen en geweld te maken. Vooral reizigers zonder-zonder (geen kaartje, geen ID) zijn berucht. Na de recente mishandeling van een conducteur staat het ov zaterdag drie minuten stil.
# ['NS-personeel', 'krijgt', 'steeds', 'vaker', 'met', 'scheldpartijen', 'en', 'geweld', 'te', 'maken.', 'Vooral', 'reizigers', 'zonder-zonder', '(geen', 'kaartje,', 'geen', 'ID)', 'zijn', '<extra_id_0>', 'mishandeling', 'van', '<extra_id_1>', 'het', 'ov', '<extra_id_2>', 'stil.']
# [4, 3, 3]
# [18, 19, 20, 21, 24, 25, 26, 29, 30, 31]
# 77
# Vier grote zonnepanelenbedrijven van Booking.com-miljonair Kees Koolen zijn failliet. Dat heeft grote gevolgen voor duizenden klanten. Hoe heeft dit kunnen gebeuren?
# ['Vier', 'grote', '<extra_id_0>', 'Kees', 'Koolen', 'zijn', 'failliet.', '<extra_id_1>', 'gevolgen', 'voor', 'duizenden', 'klanten.', 'Hoe', 'heeft', 'dit', 'kunnen', 'gebeuren?']
# [3, 3]
# [2, 3, 4, 9, 10, 11]
# 78
# Uit vrees voor escalatie verbood Washington Kyiv de inzet van zijn wapens tegen doelen in Rusland. Nu krijgt het de vrije hand, althans in de belegerde regio rond de stad Charkiv.
# ['Uit', 'vrees', 'voor', 'escalatie', 'verbood', 'Washington', 'Kyiv', 'de', 'inzet', 'van', 'zijn', 'wapens', 'tegen', 'doelen', 'in', 'Rusland.', '<extra_id_0>', 'de', '<extra_id_1>', 'in', 'de', 'belegerde', 'regio', 'rond', '<extra_id_2>']
# [3, 3, 3]
# [16, 17, 18, 20, 21, 22, 28, 29, 30]
# 79
# Met eenderde van het aantal lidstaten en eenvijfde deel van het electoraat, oefenen de Centraal- en Oost-Europese lidstaten een aanmerkelijke invloed uit op de uitkomst van de Europese verkiezingen.
# ['Met', 'eenderde', 'van', 'het', 'aantal', 'lidstaten', 'en', 'eenvijfde', 'deel', 'van', 'het', '<extra_id_0>', 'Centraal-', 'en', '<extra_id_1>', 'aanmerkelijke', 'invloed', '<extra_id_2>', 'uitkomst', 'van', 'de', 'Europese', 'verkiezingen.']
# [3, 3, 3]
# [11, 12, 13, 16, 17, 18, 21, 22, 23]
# 80
# Het Belgische cordon sanitaire staat al meer dan dertig jaar als een huis. Is dat bij de komende verkiezingen  de extreem-rechtse partij Vlaams Belang is grootste in de peilingen  nog wel vol te houden? Ze halen hun neus op voor de wens van het volk.
# ['Het', 'Belgische', 'cordon', 'sanitaire', 'staat', 'al', '<extra_id_0>', 'jaar', 'als', 'een', 'huis.', 'Is', 'dat', 'bij', 'de', '<extra_id_1>', 'extreem-rechtse', 'partij', 'Vlaams', 'Belang', 'is', 'grootste', 'in', 'de', 'peilingen', 'nog', 'wel', 'vol', 'te', 'houden?', '<extra_id_2>', 'hun', '<extra_id_3>', 'de', 'wens', '<extra_id_4>']
# [3, 3, 2, 3, 3]
# [6, 7, 8, 17, 18, 19, 34, 35, 37, 38, 39, 42, 43, 44]
# 81
# Amsterdammers mogen donderdag behalve voor het Europees Parlement ook stemmen over groen in hun stad.
# ['<extra_id_0>', 'voor', 'het', 'Europees', 'Parlement', 'ook', 'stemmen', 'over', 'groen', 'in', 'hun', 'stad.']
# [4]
# [0, 1, 2, 3]
# 82
# Shona Shukrula is voorbestemd om de eerste vrouwelijke scheidsrechter in het betaald mannenvoetbal te worden. Ze deelt die ambitie met de KNVB en vindt het heel mooi om uithangbord te zijn.
# ['Shona', 'Shukrula', 'is', 'voorbestemd', 'om', 'de', 'eerste', '<extra_id_0>', 'het', 'betaald', 'mannenvoetbal', 'te', 'worden.', 'Ze', 'deelt', 'die', 'ambitie', 'met', '<extra_id_1>', 'vindt', 'het', 'heel', 'mooi', '<extra_id_2>', 'zijn.']
# [3, 3, 3]
# [7, 8, 9, 20, 21, 22, 27, 28, 29]
# 83
# De Poolse titelverdediger Iga Swiatek wint voor de derde keer op een rij Roland Garros. Voor de 23-jarige Swiatek, vooraf de grote favoriete voor de eindzege, is het haar vijfde grandslamtitel.
# ['De', 'Poolse', 'titelverdediger', 'Iga', 'Swiatek', 'wint', 'voor', 'de', '<extra_id_0>', 'een', 'rij', '<extra_id_1>', 'de', '23-jarige', 'Swiatek,', 'vooraf', '<extra_id_2>', 'voor', 'de', 'eindzege,', 'is', 'het', 'haar', 'vijfde', 'grandslamtitel.']
# [3, 3, 3]
# [8, 9, 10, 13, 14, 15, 20, 21, 22]
# 84
# Armoedebestrijding loopt vaak stuk op verkeerde aannames van mensen met geld, zegt Tim S Jongers, zelf opgegroeid in armoede.
# ['Armoedebestrijding', 'loopt', '<extra_id_0>', 'verkeerde', '<extra_id_1>', 'met', 'geld,', 'zegt', 'Tim', 'S', 'Jongers,', 'zelf', 'opgegroeid', 'in', 'armoede.']
# [3, 3]
# [2, 3, 4, 6, 7, 8]
# 85
# De voetbalwereld rolde over haar heen en ze kreeg doodsbedreigingen, toen ze zich uitliet over de situatie bij Ajax. Toch zet psycholoog Annemieke Griffin-Zijerveld haar werk in de sport voort. Ook tijdens het EK zal ze individuele profs begeleiden, onder wie spelers van Oranje.
# ['De', 'voetbalwereld', 'rolde', 'over', 'haar', 'heen', 'en', '<extra_id_0>', 'ze', 'zich', 'uitliet', 'over', 'de', 'situatie', 'bij', 'Ajax.', 'Toch', '<extra_id_1>', 'Griffin-Zijerveld', 'haar', '<extra_id_2>', 'sport', 'voort.', 'Ook', 'tijdens', 'het', 'EK', 'zal', 'ze', 'individuele', 'profs', 'begeleiden,', 'onder', '<extra_id_3>', 'Oranje.']
# [4, 3, 3, 3]
# [7, 8, 9, 10, 20, 21, 22, 25, 26, 27, 40, 41, 42]
# 86
# Musicalactrice Bettina Holwerda moest leren dat afzeggen niet zwak is en overstemt het geadem van haar man met het gezoem van een ventilator. Ik heb misofonie, ben heel gevoelig voor geluid. In de Mezza-rubriek Hemd van het Lijf vertellen BNrs over hun gezondheid.
# ['Musicalactrice', '<extra_id_0>', 'leren', 'dat', 'afzeggen', 'niet', 'zwak', 'is', 'en', 'overstemt', 'het', 'geadem', 'van', 'haar', 'man', 'met', 'het', 'gezoem', 'van', 'een', 'ventilator.', 'Ik', 'heb', 'misofonie,', 'ben', 'heel', '<extra_id_1>', 'In', 'de', 'Mezza-rubriek', 'Hemd', '<extra_id_2>', 'vertellen', '<extra_id_3>']
# [3, 3, 3, 4]
# [1, 2, 3, 28, 29, 30, 35, 36, 37, 39, 40, 41, 42]
# 87
# Huisfeestje, de samenwerking tussen Roxy Dekker en jongensgroep Bankzitters, is anderhalve dag na lancering al een hit op de streamingdiensten. Op Spotify kwam het nummer zelfs dicht bij een record.
# ['Huisfeestje,', 'de', 'samenwerking', 'tussen', 'Roxy', 'Dekker', 'en', 'jongensgroep', 'Bankzitters,', 'is', 'anderhalve', 'dag', 'na', 'lancering', 'al', 'een', '<extra_id_0>', 'streamingdiensten.', '<extra_id_1>', 'het', 'nummer', '<extra_id_2>', 'een', 'record.']
# [3, 3, 3]
# [16, 17, 18, 20, 21, 22, 25, 26, 27]
# 88
# Shona Shukrula is voorbestemd om de eerste vrouwelijke scheidsrechter in het betaald mannenvoetbal te worden. Ze deelt die ambitie met de KNVB en vindt het heel mooi om uithangbord te zijn.
# ['Shona', 'Shukrula', 'is', 'voorbestemd', 'om', 'de', 'eerste', 'vrouwelijke', '<extra_id_0>', 'betaald', '<extra_id_1>', 'Ze', 'deelt', 'die', 'ambitie', 'met', 'de', 'KNVB', 'en', 'vindt', 'het', 'heel', 'mooi', 'om', '<extra_id_2>']
# [3, 3, 3]
# [8, 9, 10, 12, 13, 14, 28, 29, 30]
# 89
# De Amsterdamse burgemeester Halsema wilde in gesprek met pro-Palestijnse demonstranten, die dat aangrepen als een nieuwe kans om te demonsteren. Halsema prees hun engagement: Het ontroert me dat de studenten zo betrokken zijn bij internationale politiek.
# ['De', 'Amsterdamse', 'burgemeester', 'Halsema', 'wilde', '<extra_id_0>', 'pro-Palestijnse', 'demonstranten,', 'die', 'dat', 'aangrepen', 'als', 'een', 'nieuwe', 'kans', 'om', 'te', 'demonsteren.', 'Halsema', 'prees', '<extra_id_1>', 'ontroert', 'me', 'dat', '<extra_id_2>', 'zo', 'betrokken', 'zijn', '<extra_id_3>']
# [3, 3, 2, 3]
# [5, 6, 7, 22, 23, 24, 28, 29, 33, 34, 35]
# 90
# Een kaalslag dreigt onder installateurs van zonnepanelen in Nederland. Niet alleen zijn de energieprijzen gezakt, ook de lucratieve salderingsregeling heeft haar langste tijd gehad. Wat blijft er over van de stralende toekomst van zonne-energie in Nederland?
# ['Een', 'kaalslag', 'dreigt', 'onder', 'installateurs', 'van', '<extra_id_0>', 'Niet', 'alleen', 'zijn', 'de', 'energieprijzen', 'gezakt,', 'ook', 'de', 'lucratieve', 'salderingsregeling', 'heeft', 'haar', 'langste', 'tijd', '<extra_id_1>', 'blijft', 'er', 'over', 'van', '<extra_id_2>', 'van', '<extra_id_3>']
# [3, 2, 3, 3]
# [6, 7, 8, 23, 24, 29, 30, 31, 33, 34, 35]
# 91
# Na uit de hand gelopen protesten werd de campus van de Universiteit van Amsterdam voor twee dagen ten dele gesloten. Nu lijkt de rust terug te keren. Met de tentamens voor de deur hopen studenten en docenten rustig aan de bak te kunnen.
# ['Na', 'uit', 'de', 'hand', 'gelopen', 'protesten', 'werd', 'de', 'campus', 'van', '<extra_id_0>', 'Amsterdam', 'voor', 'twee', 'dagen', 'ten', 'dele', 'gesloten.', 'Nu', 'lijkt', '<extra_id_1>', 'te', 'keren.', 'Met', 'de', 'tentamens', '<extra_id_2>', 'studenten', 'en', 'docenten', 'rustig', 'aan', '<extra_id_3>', 'kunnen.']
# [3, 3, 4, 3]
# [10, 11, 12, 22, 23, 24, 30, 31, 32, 33, 39, 40, 41]
# 92
# Is dit fascisme? Het is de vraag die telkens terugkomt. Baudets opmerking over homeopathische verdunning: is dit fascisme? De bestorming van het Capitool: is dit fascisme? Poetins strijd tegen -lhbti-activisten: is dit fascisme?
# ['<extra_id_0>', 'is', 'de', 'vraag', 'die', 'telkens', 'terugkomt.', 'Baudets', 'opmerking', 'over', '<extra_id_1>', 'dit', 'fascisme?', '<extra_id_2>', 'het', 'Capitool:', 'is', 'dit', 'fascisme?', 'Poetins', 'strijd', 'tegen', '-lhbti-activisten:', 'is', 'dit', 'fascisme?']
# [4, 3, 3]
# [0, 1, 2, 3, 13, 14, 15, 18, 19, 20]
# 93
# De rectores magnifici van vijftien Nederlandse universiteiten schrijven de banden met Isralische universiteiten niet te willen verbreken. Op die manier kan de dialoog met de partners in Isral beter gevoerd worden, ook als dat schuurt met onze en andermans diepste overtuiging, schrijven ze in een open brief.
# ['De', 'rectores', 'magnifici', '<extra_id_0>', 'universiteiten', 'schrijven', 'de', 'banden', 'met', 'Isralische', 'universiteiten', 'niet', 'te', 'willen', 'verbreken.', 'Op', '<extra_id_1>', 'kan', 'de', 'dialoog', 'met', '<extra_id_2>', 'Isral', 'beter', 'gevoerd', 'worden,', 'ook', 'als', 'dat', '<extra_id_3>', 'en', '<extra_id_4>', 'schrijven', 'ze', 'in', 'een', 'open', 'brief.']
# [3, 2, 3, 3, 3]
# [3, 4, 5, 18, 19, 24, 25, 26, 34, 35, 36, 38, 39, 40]
# 94
# Met AI Overview, een nieuwe manier van Google om te zoeken, zouden consumenten kwalitatief hoogwaardige antwoorden op hun vragen moeten krijgen. Maar de zoekmachine blijkt soms verbijsterende blunders te maken.
# ['Met', 'AI', 'Overview,', 'een', 'nieuwe', 'manier', 'van', 'Google', 'om', 'te', 'zoeken,', 'zouden', '<extra_id_0>', 'antwoorden', 'op', 'hun', 'vragen', '<extra_id_1>', 'de', '<extra_id_2>', 'verbijsterende', 'blunders', 'te', 'maken.']
# [3, 3, 3]
# [12, 13, 14, 19, 20, 21, 23, 24, 25]
# 95
# Zelden won een renner een van de drie grote rondes met zo veel overmacht als Tadej Pogacar de Giro dItalia van 2024. Dat is grotendeels zijn verdienste, maar de Sloveen trof ook tegenstanders die al in de tweede etappe het hoofd in de schoot legden.
# ['Zelden', 'won', 'een', 'renner', 'een', 'van', 'de', 'drie', 'grote', 'rondes', 'met', 'zo', '<extra_id_0>', 'Tadej', 'Pogacar', 'de', 'Giro', 'dItalia', 'van', '2024.', 'Dat', 'is', '<extra_id_1>', 'verdienste,', 'maar', 'de', 'Sloveen', 'trof', 'ook', 'tegenstanders', '<extra_id_2>', 'de', '<extra_id_3>', 'hoofd', 'in', '<extra_id_4>']
# [3, 2, 3, 3, 3]
# [12, 13, 14, 24, 25, 33, 34, 35, 37, 38, 39, 42, 43, 44]
# 96
# De van televisie bekende Henritte Momma is eind vorige maand op 90-jarige leeftijd overleden. Miljoenen Nederlanders leerden haar de afgelopen jaren kennen als de liefdevolle en zorgzame moeder van de autistische kunstenaar Kees Momma.
# ['De', 'van', 'televisie', 'bekende', 'Henritte', 'Momma', 'is', 'eind', 'vorige', 'maand', 'op', '90-jarige', 'leeftijd', 'overleden.', 'Miljoenen', 'Nederlanders', 'leerden', '<extra_id_0>', 'jaren', 'kennen', 'als', 'de', 'liefdevolle', 'en', '<extra_id_1>', 'autistische', '<extra_id_2>']
# [3, 4, 3]
# [17, 18, 19, 26, 27, 28, 29, 31, 32, 33]
# 97
# De laatste verkeerstuin van Nederland in zijn soort dreigt te verdwijnen nu de gemeente Utrecht de subsidie stopzet. Eeuwig zonde, vinden de vrijwilligers.
# ['De', 'laatste', 'verkeerstuin', 'van', 'Nederland', 'in', 'zijn', 'soort', 'dreigt', 'te', 'verdwijnen', 'nu', '<extra_id_0>', 'subsidie', 'stopzet.', 'Eeuwig', '<extra_id_1>', 'vrijwilligers.']
# [4, 3]
# [12, 13, 14, 15, 19, 20, 21]
# 98
# Nog nooit kregen zo weinig babys borstvoeding. Er wordt te weinig ruimte voor gegeven, zeggen jonge moeders in Lelystad.
# ['Nog', 'nooit', 'kregen', 'zo', '<extra_id_0>', 'Er', 'wordt', 'te', '<extra_id_1>', 'gegeven,', 'zeggen', 'jonge', 'moeders', 'in', 'Lelystad.']
# [3, 3]
# [4, 5, 6, 10, 11, 12]
# 99
# Londen is onvoldoende voorbereid op de gevolgen van klimaatverandering. Zo moet de waterkering Thames Barrier, die veel meer gebruikt wordt dan gedacht, eerder worden vervangen.
# ['Londen', 'is', 'onvoldoende', 'voorbereid', 'op', 'de', 'gevolgen', 'van', 'klimaatverandering.', 'Zo', 'moet', 'de', 'waterkering', 'Thames', 'Barrier,', '<extra_id_0>', 'gebruikt', '<extra_id_1>', 'eerder', '<extra_id_2>']
# [3, 3, 2]
# [15, 16, 17, 19, 20, 21, 23, 24]

# %%
masked_sequences_df = masked_sequences_df.dropna(axis='rows')
masked_sequences_df
# Out:
#                         Input sequence (ground truth)  \
# 0   Met een spectaculaire reddingsoperatie wist he...
# 1   Met een spectaculaire reddingsoperatie wist he...
# 2   Op 1 juni begint de Nederlander Hermen Hulst a...
# 3   De liberaal-conservatieve Nieuw-Vlaamse Allian...
# 4   De elfde editie van de Willem IV Rally was een...
# ..                                                ...
# 95  Zelden won een renner een van de drie grote ro...
# 96  De van televisie bekende Henritte Momma is ein...
# 97  De laatste verkeerstuin van Nederland in zijn ...
# 98  Nog nooit kregen zo weinig babys borstvoeding....
# 99  Londen is onvoldoende voorbereid op de gevolge...
#
#                               Input sequence (masked)  \
# 0   Met een spectaculaire reddingsoperatie wist he...
# 1   Met een spectaculaire <extra_id_0> Isralische ...
# 2   Op 1 juni begint de Nederlander Hermen Hulst <...
# 3   De liberaal-conservatieve Nieuw-Vlaamse <extra...
# 4   <extra_id_0> van de Willem IV Rally was een gr...
# ..                                                ...
# 95  Zelden won een renner een van de drie grote ro...
# 96  De van televisie bekende Henritte Momma is ein...
# 97  De laatste verkeerstuin van Nederland in zijn ...
# 98  Nog nooit kregen zo <extra_id_0> Er wordt te <...
# 99  Londen is onvoldoende voorbereid op de gevolge...
#
#                                         Masked tokens  \
# 0   [leger zaterdag vier gijzelaars, gijzelaars di...
# 1   [reddingsoperatie wist het, te bevrijden. De p...
# 2   [als ceo van, Entertainment, de maker, Hij kri...
# 3   [Alliantie (N-VA) blijft de, Belgische media o...
# 4   [De elfde editie, het Ronald McDonald, Rotterd...
# ..                                                ...
# 95  [veel overmacht als, grotendeels zijn, die al ...
# 96  [haar de afgelopen, zorgzame moeder van de, ku...
# 97         [de gemeente Utrecht de, zonde, vinden de]
# 98   [weinig babys borstvoeding., weinig ruimte voor]
# 99  [die veel meer, wordt dan gedacht,, worden ver...
#
#     Number of masked tokens  Masking percentage  Duplicate count
# 0                        13                30.0                1
# 1                        13                30.0                1
# 2                        14                30.0                1
# 3                        13                30.0                1
# 4                        15                30.0                1
# ..                      ...                 ...              ...
# 95                       14                30.0                1
# 96                       10                30.0                1
# 97                        7                30.0                1
# 98                        6                30.0                1
# 99                        8                30.0                1
#
# [100 rows x 6 columns]

# %%
masked_sequences_df.iloc[2]['Input sequence (masked)']
# Out:
# 'Op 1 juni begint de Nederlander Hermen Hulst <extra_id_0> Sony Interactive <extra_id_1> van PlayStation. Voorheen produceerde Hulst de succesvolle gameseries Killzone en Horizon. <extra_id_2> taak om s werelds grootste gamebedrijf door een tumultueuze <extra_id_3> game-industrie <extra_id_4>'

# %%
masked_sequences_df.to_csv(f"..\\data\\{TYPE}\\masked_input\\{MASK_LEVEL_FOLDER}\\masked_sequences_{TITLE}.csv", index=False)
